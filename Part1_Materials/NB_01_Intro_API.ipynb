# %% [markdown]
# # Trading with Python and Binance - Introduction to the API

# %% [markdown]
# __Insert your Credentials here__:

# %%
api_key = "qTjXOGG9StwjzKAkA8ztSxNYfb1GC51Fb4VdIxvxjlyJRn5mwNIMaYj70Y0jVocu"
secret_key = "DYvwOFI538z1qI9YoeqHMwySydXEXQnXwkSby2KGU8y78m06b54rGWl9FH49sI6M"

# %% [markdown]
# ## Installing required Libraries/Packages

# %% [markdown]
# Install python-binance with:
# - pip install python-binance

# %% [markdown]
# (first: conda update anaconda)

# %% [markdown]
# ## Creating a Connection

# %%
from binance.client import Client

# %% [markdown]
# If you have an account on __Binance.com__ (non-US users)

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com")

# %%
client

# %%
client.get_account() # account details
# Out:
# {'makerCommission': 10,
#  'takerCommission': 10,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'brokered': False,
#  'updateTime': 1663782509357,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '0.00066492', 'locked': '0.00000000'},
#   {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GAS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HSR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MCO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OMG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YOYO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LRC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNGLS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STRAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BQX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KNC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XVG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOTA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CVC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MTL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SALT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NULS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MTH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ENG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZEC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DGD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DASH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POWR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REQ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ENJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VEN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MOD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STORJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KMD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RCN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EDO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DATA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DLT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MANA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RDN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AMB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GVT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XZC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QSP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LSK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TNB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LEND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CMT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WAVES', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WABI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ELF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AION', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WINGS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BRD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEBL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NAV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRIG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'APPC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RLC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'INS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PIVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STEEM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NANO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BLZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SYS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RPX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NCASH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZIL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STORM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XEM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WAN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WPR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QLC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GRS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CLOAK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LOOM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZEN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SKY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'THETA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOTX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QKC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NPXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KEY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NAS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MFT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DENT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IQ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARDR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VET', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOCK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POLY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VTHO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PHX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RVN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DCR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MITH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHABC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHSV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FET', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TFUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CELR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MATIC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATOM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PHB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FTM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDSB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ERD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOGE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BGBP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DUSK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ANKR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WIN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TUSDB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COCOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PERL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TOMO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEAM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HBAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XTZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NGN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DGB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NKN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GBP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EUR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KAVA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RUB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UAH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARPA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CTXC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AERGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TROY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BRL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VITE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FTT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OGN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DREP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TCT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MBL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COTI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BKRW', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HIVE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SOL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IDRT', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'CTSI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BIDR', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'STMX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IRIS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MKR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DAI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADAUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADADOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINKUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINKDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RUNE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XTZUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XTZDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AVA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SRM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ANT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CRV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SAND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OCEAN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUNA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IDEX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RSR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PAXG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WNXM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KSM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFII', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DIA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UMA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRXUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRXDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOTUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOTDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NBS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WING', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SWRV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CREAM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OXT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AVAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BURGER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SCRT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XVS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SPARTA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALPHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ORN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UTK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'INJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FILDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FILUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CTK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EASY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUDIO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AKRO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HARD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KP3R', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RENBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SLP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STRAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CVP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FOR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FRONT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ROSE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HEGIC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVEUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVEDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PROM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BETH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SKL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COVER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GHST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLMUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLMDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JUV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PSG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BVND', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'GRT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CELO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TWT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REEF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ASR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RIF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRU', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DEXE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CKB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIRO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LIT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PROS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VAI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SFP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DODO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUCTION', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UFT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TVK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BADGER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALICE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DEGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BIFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PERP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RAMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUPER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CFX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TKO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EPS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PUNDIX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MIR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FORTH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SHIB', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'POLS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MASK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGIX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NU', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KLAY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TORN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KEEP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ERN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BOND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MLN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'C98', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLOW', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QUICK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RAY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MINA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CLV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XEC', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'ALPACA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FARM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VGX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MBOX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WAXP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GNO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DYDX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GALA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ILV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YGG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BETA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RAD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RARE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SSV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LAZIO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MOVR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHESS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ASTR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RGT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CITY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ENS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PORTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JASMY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PLA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PYR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SANTOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RNDR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALCX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ANY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VOXEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BICO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLUX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HIGH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OOKI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PEOPLE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SPELL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JOE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BDOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GLMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IMX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LOKA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTTC', 'free': '0.0', 'locked': '0.0'},
#   {'asset': 'SOLO', 'free': '0.37104326', 'locked': '0.00000000'},
#   {'asset': 'ANC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'API3', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XNO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WOO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALPINE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'T', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NBT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'APE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GMT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MOB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BSW', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MULTI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GAL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEXO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EPX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LDO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUNC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LEVER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STG', 'free': '0.00000000', 'locked': '0.00000000'}],
#  'permissions': ['SPOT']}

# %% [markdown]
# ## General account/system Info

# %% [markdown]
# __Official API Documentation Site:__

# %% [markdown]
# https://binance-docs.github.io/apidocs/spot/en/#introduction

# %% [markdown]
# __API Wrapper (python-binance) Documentation Site:__

# %% [markdown]
# https://python-binance.readthedocs.io/en/latest/index.html

# %%
import pandas as pd
from binance.client import Client

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com")

# %%
client.ping() # Test connectivity
# Out:
# {}

# %%
client.get_system_status()
# Out:
# {'status': 0, 'msg': 'normal'}

# %%
account = client.get_account()
account
# Out:
# {'makerCommission': 10,
#  'takerCommission': 10,
#  'buyerCommission': 0,
#  'sellerCommission': 0,
#  'canTrade': True,
#  'canWithdraw': True,
#  'canDeposit': True,
#  'brokered': False,
#  'updateTime': 1663782509357,
#  'accountType': 'SPOT',
#  'balances': [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNB', 'free': '0.00066492', 'locked': '0.00000000'},
#   {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GAS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HSR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MCO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OMG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YOYO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LRC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNGLS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STRAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BQX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KNC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XVG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOTA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CVC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MTL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SALT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NULS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MTH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ENG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZEC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DGD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DASH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POWR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REQ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ENJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VEN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MOD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STORJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KMD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RCN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EDO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DATA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DLT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MANA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RDN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AMB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GVT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XZC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QSP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LSK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TNB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LEND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CMT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WAVES', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WABI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ELF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AION', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WINGS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BRD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEBL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NAV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRIG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'APPC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHAT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RLC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'INS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PIVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STEEM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NANO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BLZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SYS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RPX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NCASH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZIL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STORM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XEM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WAN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WPR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QLC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GRS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CLOAK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LOOM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZEN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SKY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'THETA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IOTX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QKC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NPXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KEY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NAS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MFT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DENT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IQ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARDR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VET', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOCK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POLY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VTHO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PHX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RVN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DCR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MITH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHABC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHSV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FET', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TFUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CELR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MATIC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATOM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PHB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ONE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FTM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDSB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ERD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOGE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BGBP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DUSK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ANKR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WIN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TUSDB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COCOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PERL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TOMO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEAM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HBAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XTZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NGN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DGB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NKN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GBP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EUR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KAVA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RUB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UAH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ARPA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CTXC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AERGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TROY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BRL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VITE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FTT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OGN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DREP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TCT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ZAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MBL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COTI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BKRW', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HIVE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SOL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IDRT', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'CTSI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BIDR', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'STMX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IRIS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MKR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SNX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DAI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ETHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADAUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ADADOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINKUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINKDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RUNE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNBDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XTZUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XTZDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AVA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SRM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ANT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CRV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SAND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OCEAN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUNA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IDEX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RSR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PAXG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WNXM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KSM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFII', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DIA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UMA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRXUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EOSDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRXDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XRPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOTUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DOTDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NBS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WING', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SWRV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CREAM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OXT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AVAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BURGER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SCRT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XVS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SPARTA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALPHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ORN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UTK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VIDT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SXPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'INJ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FILDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FILUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YFIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CTK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EASY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUDIO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AKRO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HARD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KP3R', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RENBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SLP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STRAX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UNFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CVP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BCHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FOR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FRONT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ROSE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MDX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HEGIC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVEUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AAVEDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PROM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BETH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SKL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'COVER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GHST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUSHIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLMUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XLMDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JUV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PSG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BVND', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'GRT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CELO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TWT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REEF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ASR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RIF', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTCST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRU', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DEXE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CKB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIRO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LIT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PROS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VAI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SFP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FXS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DODO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUCTION', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UFT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PHA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TVK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BADGER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'POND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALICE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DEGO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BIFI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LINA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PERP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RAMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SUPER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CFX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TKO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AUTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EPS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PUNDIX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TLM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': '1INCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MIR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FORTH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EZ', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ICP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SHIB', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'POLS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MASK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LPT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGIX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ATA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NU', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KLAY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TORN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KEEP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ERN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BOND', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MLN', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'C98', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLOW', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QUICK', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RAY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MINA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'QNT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CLV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XEC', 'free': '0.00', 'locked': '0.00'},
#   {'asset': 'ALPACA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FARM', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VGX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MBOX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WAXP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'TRIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GNO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USDP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DYDX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GALA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ILV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'YGG', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FIDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BETA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RAD', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RARE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SSV', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LAZIO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MOVR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CHESS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'DAR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ASTR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BNX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RGT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CITY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ENS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PORTO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JASMY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'AMP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PLA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PYR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SANTOS', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'RNDR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALCX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ANY', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'VOXEL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BICO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'FLUX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'UST', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'HIGH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OOKI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'CVX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'PEOPLE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'SPELL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'JOE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BDOT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GLMR', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ACH', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'IMX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LOKA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BTTC', 'free': '0.0', 'locked': '0.0'},
#   {'asset': 'SOLO', 'free': '0.37104326', 'locked': '0.00000000'},
#   {'asset': 'ANC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'API3', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'XNO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'WOO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'ALPINE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'T', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NBT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'KDA', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'APE', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GMT', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MOB', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'BSW', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'MULTI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'REI', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'GAL', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'NEXO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'EPX', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LDO', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'USTC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LUNC', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'OP', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'LEVER', 'free': '0.00000000', 'locked': '0.00000000'},
#   {'asset': 'STG', 'free': '0.00000000', 'locked': '0.00000000'}],
#  'permissions': ['SPOT']}

# %%
account["accountType"] # account Type (Spot, Futures)
# Out:
# 'SPOT'

# %%
pd.to_datetime(account["updateTime"], unit = "ms") # Last Update -> UTC Time
# Out:
# Timestamp('2022-09-21 17:48:29.357000')

# %%
account["balances"] # asset balances
# Out:
# [{'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NEO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNB', 'free': '0.00066492', 'locked': '0.00000000'},
#  {'asset': 'QTUM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GAS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HSR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OAX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MCO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ICN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OMG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YOYO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LRC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SNGLS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STRAT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BQX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FUN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KNC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CDT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XVG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IOTA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SNM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LINK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CVC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MDA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MTL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SALT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NULS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MTH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ADX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ENG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZEC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DGD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DASH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POWR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REQ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XMR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EVX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VIB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ENJ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VEN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MOD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STORJ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KMD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RCN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EDO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DATA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DLT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MANA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PPT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RDN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AMB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCPT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GVT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XZC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QSP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LSK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TNB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ADA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LEND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XLM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CMT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WAVES', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WABI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GTO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ICX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ELF', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AION', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WINGS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BRD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NEBL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NAV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LUN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRIG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'APPC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CHAT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RLC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'INS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PIVX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IOST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STEEM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NANO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VIA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BLZ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SYS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RPX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NCASH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ONT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZIL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STORM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XEM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WAN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WPR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QLC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GRS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CLOAK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LOOM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZEN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SKY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'THETA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IOTX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QKC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AGI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NPXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KEY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NAS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MFT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DENT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IQ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARDR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HOT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VET', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOCK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POLY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VTHO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ONG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PHX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PAX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RVN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DCR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MITH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHABC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHSV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FET', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TFUEL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CELR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MATIC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ATOM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PHB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ONE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FTM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTCB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDSB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CHZ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ALGO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ERD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOGE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BGBP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DUSK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ANKR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WIN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TUSDB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COCOS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PERL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TOMO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BEAM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HBAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XTZ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NGN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DGB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NKN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GBP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EUR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KAVA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RUB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UAH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ARPA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CTXC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AERGO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TROY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BRL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VITE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FTT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AUD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OGN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DREP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETHBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETHBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRPBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRPBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOSBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOSBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TCT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WRX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LTO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ZAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MBL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COTI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BKRW', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNBBULL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNBBEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HIVE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STPT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SOL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IDRT', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'CTSI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CHR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FIO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BIDR', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'STMX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MDT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COMP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IRIS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MKR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SXP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SNX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DAI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ETHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ADAUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ADADOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LINKUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LINKDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RUNE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNBUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNBDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XTZUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XTZDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AVA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YFI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SRM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ANT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CRV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SAND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OCEAN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NMR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LUNA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IDEX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RSR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PAXG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WNXM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BZRX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KSM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUSHI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YFII', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DIA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BEL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UMA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOSUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRXUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EOSDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRXDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XRPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOTUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DOTDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NBS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WING', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SWRV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LTCUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LTCDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CREAM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UNI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OXT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AVAX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BURGER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FLM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SCRT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XVS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CAKE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SPARTA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UNIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UNIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ALPHA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ORN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UTK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NEAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VIDT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AAVE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FIL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SXPUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SXPDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'INJ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FILDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FILUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YFIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YFIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CTK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EASY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AUDIO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BOT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AKRO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HARD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KP3R', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RENBTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SLP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STRAX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UNFI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CVP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BCHA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FOR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FRONT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ROSE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MDX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HEGIC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AAVEUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AAVEDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PROM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BETH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SKL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GLM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUSD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'COVER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GHST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUSHIUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUSHIDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XLMUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XLMDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DF', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JUV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PSG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BVND', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'GRT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CELO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TWT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REEF', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ATM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ASR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': '1INCH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RIF', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTCST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRU', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DEXE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CKB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FIRO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LIT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PROS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VAI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SFP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FXS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DODO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AUCTION', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UFT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ACM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PHA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TVK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BADGER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FIS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'POND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ALICE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DEGO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BIFI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LINA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PERP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RAMP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SUPER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CFX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TKO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AUTO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EPS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PUNDIX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TLM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': '1INCHUP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': '1INCHDOWN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MIR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FORTH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EZ', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ICP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SHIB', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'POLS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MASK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LPT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AGIX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ATA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NU', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KLAY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TORN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KEEP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ERN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BOND', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MLN', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'C98', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FLOW', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QUICK', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RAY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MINA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'QNT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CLV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XEC', 'free': '0.00', 'locked': '0.00'},
#  {'asset': 'ALPACA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FARM', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VGX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MBOX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WAXP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'TRIBE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GNO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USDP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DYDX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GALA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ILV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'YGG', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FIDA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AGLD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BETA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RAD', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RARE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SSV', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LAZIO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MOVR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CHESS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'DAR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ACA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ASTR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BNX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RGT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CITY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ENS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PORTO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JASMY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'AMP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PLA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PYR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SANTOS', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'RNDR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ALCX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ANY', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'VOXEL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BICO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'FLUX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'UST', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'HIGH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OOKI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'CVX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'PEOPLE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'SPELL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'JOE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BDOT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GLMR', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ACH', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'IMX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LOKA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BTTC', 'free': '0.0', 'locked': '0.0'},
#  {'asset': 'SOLO', 'free': '0.37104326', 'locked': '0.00000000'},
#  {'asset': 'ANC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'API3', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'XNO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'WOO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'ALPINE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'T', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NBT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'KDA', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'APE', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GMT', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MOB', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'BSW', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'MULTI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'REI', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'GAL', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'NEXO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'EPX', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LDO', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'USTC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LUNC', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'OP', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'LEVER', 'free': '0.00000000', 'locked': '0.00000000'},
#  {'asset': 'STG', 'free': '0.00000000', 'locked': '0.00000000'}]

# %%
df = pd.DataFrame(account["balances"])
df
# Out:
#      asset        free      locked
# 0      BTC  0.00000000  0.00000000
# 1      LTC  0.00000000  0.00000000
# 2      ETH  0.00000000  0.00000000
# 3      NEO  0.00000000  0.00000000
# 4      BNB  0.00066492  0.00000000
# ..     ...         ...         ...
# 512   USTC  0.00000000  0.00000000
# 513   LUNC  0.00000000  0.00000000
# 514     OP  0.00000000  0.00000000
# 515  LEVER  0.00000000  0.00000000
# 516    STG  0.00000000  0.00000000
#
# [517 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   asset   517 non-null    object
#  1   free    517 non-null    object
#  2   locked  517 non-null    object
# dtypes: object(3)
# memory usage: 12.2+ KB

# %%
df.free = pd.to_numeric(df.free, errors="coerce")
df.locked = pd.to_numeric(df.locked, errors="coerce")

# %%
df.loc[df.free > 0]
# Out:
#     asset      free  locked
# 4     BNB  0.000665     0.0
# 493  SOLO  0.371043     0.0

# %%
client.get_asset_balance(asset = "btc")
# Out:
# {'asset': 'BTC', 'free': '0.00000000', 'locked': '0.00000000'}

# %%
client.get_asset_balance(asset = "BUSD")
# Out:
# {'asset': 'BUSD', 'free': '0.08750000', 'locked': '16.91250000'}

# %%
float(client.get_asset_balance(asset="EUR")["free"])
# Out:
# 0.0

# %%
snap = client.get_account_snapshot(type = "SPOT") # daily account snapshot
snap
# Out:
# {'code': 200,
#  'msg': '',
#  'snapshotVos': [{'type': 'spot',
#    'updateTime': 1663199999000,
#    'data': {'totalAssetOfBtc': '0.00595454',
#     'balances': [{'asset': 'ADA', 'free': '0', 'locked': '0'},
#      {'asset': 'AUDIO', 'free': '0', 'locked': '0'},
#      {'asset': 'AXS', 'free': '0', 'locked': '0'},
#      {'asset': 'BAT', 'free': '0', 'locked': '0'},
#      {'asset': 'BCH', 'free': '0', 'locked': '0'},
#      {'asset': 'BNB', 'free': '0.00075305', 'locked': '0'},
#      {'asset': 'BTC', 'free': '0', 'locked': '0'},
#      {'asset': 'BURGER', 'free': '0', 'locked': '0'},
#      {'asset': 'BUSD', 'free': '0', 'locked': '0'},
#      {'asset': 'C98', 'free': '0', 'locked': '0'},
#      {'asset': 'CFX', 'free': '0', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0', 'locked': '0'},
#      {'asset': 'GALA', 'free': '0', 'locked': '0'},
#      {'asset': 'HBAR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDMANA', 'free': '0', 'locked': '0'},
#      {'asset': 'LTC', 'free': '0', 'locked': '0'},
#      {'asset': 'MANA', 'free': '0', 'locked': '0'},
#      {'asset': 'MATIC', 'free': '0', 'locked': '0'},
#      {'asset': 'MIR', 'free': '0', 'locked': '0'},
#      {'asset': 'RNDR', 'free': '0', 'locked': '0'},
#      {'asset': 'RUNE', 'free': '0', 'locked': '0'},
#      {'asset': 'SHIB', 'free': '0', 'locked': '0'},
#      {'asset': 'SOL', 'free': '0', 'locked': '0'},
#      {'asset': 'SOLO', 'free': '0.37104326', 'locked': '0'},
#      {'asset': 'TRX', 'free': '0', 'locked': '0'},
#      {'asset': 'UNI', 'free': '0', 'locked': '0'},
#      {'asset': 'USDT', 'free': '120.25355361', 'locked': '0'},
#      {'asset': 'VET', 'free': '0', 'locked': '0'},
#      {'asset': 'XEC', 'free': '0', 'locked': '0'},
#      {'asset': 'XRP', 'free': '0', 'locked': '0'},
#      {'asset': 'XTZ', 'free': '0', 'locked': '0'},
#      {'asset': 'YFII', 'free': '0', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1663286399000,
#    'data': {'totalAssetOfBtc': '0.00611443',
#     'balances': [{'asset': 'ADA', 'free': '0', 'locked': '0'},
#      {'asset': 'AUDIO', 'free': '0', 'locked': '0'},
#      {'asset': 'AXS', 'free': '0', 'locked': '0'},
#      {'asset': 'BAT', 'free': '0', 'locked': '0'},
#      {'asset': 'BCH', 'free': '0', 'locked': '0'},
#      {'asset': 'BNB', 'free': '0.00075305', 'locked': '0'},
#      {'asset': 'BTC', 'free': '0', 'locked': '0'},
#      {'asset': 'BURGER', 'free': '0', 'locked': '0'},
#      {'asset': 'BUSD', 'free': '0', 'locked': '0'},
#      {'asset': 'C98', 'free': '0', 'locked': '0'},
#      {'asset': 'CFX', 'free': '0', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0', 'locked': '0'},
#      {'asset': 'GALA', 'free': '0', 'locked': '0'},
#      {'asset': 'HBAR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDMANA', 'free': '0', 'locked': '0'},
#      {'asset': 'LTC', 'free': '0', 'locked': '0'},
#      {'asset': 'MANA', 'free': '0', 'locked': '0'},
#      {'asset': 'MATIC', 'free': '0', 'locked': '0'},
#      {'asset': 'MIR', 'free': '0', 'locked': '0'},
#      {'asset': 'RNDR', 'free': '0', 'locked': '0'},
#      {'asset': 'RUNE', 'free': '0', 'locked': '0'},
#      {'asset': 'SHIB', 'free': '0', 'locked': '0'},
#      {'asset': 'SOL', 'free': '0', 'locked': '0'},
#      {'asset': 'SOLO', 'free': '0.37104326', 'locked': '0'},
#      {'asset': 'TRX', 'free': '0', 'locked': '0'},
#      {'asset': 'UNI', 'free': '0', 'locked': '0'},
#      {'asset': 'USDT', 'free': '120.25355361', 'locked': '0'},
#      {'asset': 'VET', 'free': '0', 'locked': '0'},
#      {'asset': 'XEC', 'free': '0', 'locked': '0'},
#      {'asset': 'XRP', 'free': '0', 'locked': '0'},
#      {'asset': 'XTZ', 'free': '0', 'locked': '0'},
#      {'asset': 'YFII', 'free': '0', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1663372799000,
#    'data': {'totalAssetOfBtc': '0.00001045',
#     'balances': [{'asset': 'ADA', 'free': '0', 'locked': '0'},
#      {'asset': 'AUDIO', 'free': '0', 'locked': '0'},
#      {'asset': 'AXS', 'free': '0', 'locked': '0'},
#      {'asset': 'BAT', 'free': '0', 'locked': '0'},
#      {'asset': 'BCH', 'free': '0', 'locked': '0'},
#      {'asset': 'BNB', 'free': '0.00075305', 'locked': '0'},
#      {'asset': 'BTC', 'free': '0', 'locked': '0'},
#      {'asset': 'BURGER', 'free': '0', 'locked': '0'},
#      {'asset': 'BUSD', 'free': '0', 'locked': '0'},
#      {'asset': 'C98', 'free': '0', 'locked': '0'},
#      {'asset': 'CFX', 'free': '0', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0', 'locked': '0'},
#      {'asset': 'GALA', 'free': '0', 'locked': '0'},
#      {'asset': 'HBAR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDMANA', 'free': '0', 'locked': '0'},
#      {'asset': 'LTC', 'free': '0', 'locked': '0'},
#      {'asset': 'MANA', 'free': '0', 'locked': '0'},
#      {'asset': 'MATIC', 'free': '0', 'locked': '0'},
#      {'asset': 'MIR', 'free': '0', 'locked': '0'},
#      {'asset': 'RNDR', 'free': '0', 'locked': '0'},
#      {'asset': 'RUNE', 'free': '0', 'locked': '0'},
#      {'asset': 'SHIB', 'free': '0', 'locked': '0'},
#      {'asset': 'SOL', 'free': '0', 'locked': '0'},
#      {'asset': 'SOLO', 'free': '0.37104326', 'locked': '0'},
#      {'asset': 'TRX', 'free': '0', 'locked': '0'},
#      {'asset': 'UNI', 'free': '0', 'locked': '0'},
#      {'asset': 'USDT', 'free': '0', 'locked': '0'},
#      {'asset': 'VET', 'free': '0', 'locked': '0'},
#      {'asset': 'XEC', 'free': '0', 'locked': '0'},
#      {'asset': 'XRP', 'free': '0', 'locked': '0'},
#      {'asset': 'XTZ', 'free': '0', 'locked': '0'},
#      {'asset': 'YFII', 'free': '0', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1663459199000,
#    'data': {'totalAssetOfBtc': '0.00001045',
#     'balances': [{'asset': 'ADA', 'free': '0', 'locked': '0'},
#      {'asset': 'AUDIO', 'free': '0', 'locked': '0'},
#      {'asset': 'AXS', 'free': '0', 'locked': '0'},
#      {'asset': 'BAT', 'free': '0', 'locked': '0'},
#      {'asset': 'BCH', 'free': '0', 'locked': '0'},
#      {'asset': 'BNB', 'free': '0.00075305', 'locked': '0'},
#      {'asset': 'BTC', 'free': '0', 'locked': '0'},
#      {'asset': 'BURGER', 'free': '0', 'locked': '0'},
#      {'asset': 'BUSD', 'free': '0', 'locked': '0'},
#      {'asset': 'C98', 'free': '0', 'locked': '0'},
#      {'asset': 'CFX', 'free': '0', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0', 'locked': '0'},
#      {'asset': 'GALA', 'free': '0', 'locked': '0'},
#      {'asset': 'HBAR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDMANA', 'free': '0', 'locked': '0'},
#      {'asset': 'LTC', 'free': '0', 'locked': '0'},
#      {'asset': 'MANA', 'free': '0', 'locked': '0'},
#      {'asset': 'MATIC', 'free': '0', 'locked': '0'},
#      {'asset': 'MIR', 'free': '0', 'locked': '0'},
#      {'asset': 'RNDR', 'free': '0', 'locked': '0'},
#      {'asset': 'RUNE', 'free': '0', 'locked': '0'},
#      {'asset': 'SHIB', 'free': '0', 'locked': '0'},
#      {'asset': 'SOL', 'free': '0', 'locked': '0'},
#      {'asset': 'SOLO', 'free': '0.37104326', 'locked': '0'},
#      {'asset': 'TRX', 'free': '0', 'locked': '0'},
#      {'asset': 'UNI', 'free': '0', 'locked': '0'},
#      {'asset': 'USDT', 'free': '0', 'locked': '0'},
#      {'asset': 'VET', 'free': '0', 'locked': '0'},
#      {'asset': 'XEC', 'free': '0', 'locked': '0'},
#      {'asset': 'XRP', 'free': '0', 'locked': '0'},
#      {'asset': 'XTZ', 'free': '0', 'locked': '0'},
#      {'asset': 'YFII', 'free': '0', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1663545599000,
#    'data': {'totalAssetOfBtc': '0.00315212',
#     'balances': [{'asset': 'ADA', 'free': '0', 'locked': '0'},
#      {'asset': 'AUDIO', 'free': '0', 'locked': '0'},
#      {'asset': 'AXS', 'free': '0', 'locked': '0'},
#      {'asset': 'BAT', 'free': '0', 'locked': '0'},
#      {'asset': 'BCH', 'free': '0', 'locked': '0'},
#      {'asset': 'BNB', 'free': '0.00075305', 'locked': '0'},
#      {'asset': 'BTC', 'free': '0', 'locked': '0'},
#      {'asset': 'BURGER', 'free': '0', 'locked': '0'},
#      {'asset': 'BUSD', 'free': '60', 'locked': '0'},
#      {'asset': 'C98', 'free': '0', 'locked': '0'},
#      {'asset': 'CFX', 'free': '0', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0', 'locked': '0'},
#      {'asset': 'GALA', 'free': '0', 'locked': '0'},
#      {'asset': 'HBAR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDMANA', 'free': '0', 'locked': '0'},
#      {'asset': 'LTC', 'free': '0', 'locked': '0'},
#      {'asset': 'MANA', 'free': '0', 'locked': '0'},
#      {'asset': 'MATIC', 'free': '0', 'locked': '0'},
#      {'asset': 'MIR', 'free': '0', 'locked': '0'},
#      {'asset': 'RNDR', 'free': '0', 'locked': '0'},
#      {'asset': 'RUNE', 'free': '0', 'locked': '0'},
#      {'asset': 'SHIB', 'free': '0', 'locked': '0'},
#      {'asset': 'SOL', 'free': '0', 'locked': '0'},
#      {'asset': 'SOLO', 'free': '0.37104326', 'locked': '0'},
#      {'asset': 'TRX', 'free': '0', 'locked': '0'},
#      {'asset': 'UNI', 'free': '0', 'locked': '0'},
#      {'asset': 'USDT', 'free': '0.9941', 'locked': '0'},
#      {'asset': 'VET', 'free': '0', 'locked': '0'},
#      {'asset': 'XEC', 'free': '0', 'locked': '0'},
#      {'asset': 'XRP', 'free': '0', 'locked': '0'},
#      {'asset': 'XTZ', 'free': '0', 'locked': '0'},
#      {'asset': 'YFII', 'free': '0', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1663631999000,
#    'data': {'totalAssetOfBtc': '0.00313094',
#     'balances': [{'asset': 'ADA', 'free': '0', 'locked': '0'},
#      {'asset': 'AUDIO', 'free': '0', 'locked': '0'},
#      {'asset': 'AXS', 'free': '0', 'locked': '0'},
#      {'asset': 'BAT', 'free': '0', 'locked': '0'},
#      {'asset': 'BCH', 'free': '0', 'locked': '0'},
#      {'asset': 'BNB', 'free': '0.00066492', 'locked': '0'},
#      {'asset': 'BTC', 'free': '0', 'locked': '0'},
#      {'asset': 'BURGER', 'free': '0', 'locked': '0'},
#      {'asset': 'BUSD', 'free': '60', 'locked': '0'},
#      {'asset': 'C98', 'free': '0', 'locked': '0'},
#      {'asset': 'CFX', 'free': '0', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0', 'locked': '0'},
#      {'asset': 'GALA', 'free': '0', 'locked': '0'},
#      {'asset': 'HBAR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDMANA', 'free': '0', 'locked': '0'},
#      {'asset': 'LTC', 'free': '0', 'locked': '0'},
#      {'asset': 'MANA', 'free': '0', 'locked': '0'},
#      {'asset': 'MATIC', 'free': '0', 'locked': '0'},
#      {'asset': 'MIR', 'free': '0', 'locked': '0'},
#      {'asset': 'RNDR', 'free': '0', 'locked': '0'},
#      {'asset': 'RUNE', 'free': '0', 'locked': '0'},
#      {'asset': 'SHIB', 'free': '0', 'locked': '0'},
#      {'asset': 'SOL', 'free': '0', 'locked': '0'},
#      {'asset': 'SOLO', 'free': '0.37104326', 'locked': '0'},
#      {'asset': 'TRX', 'free': '0', 'locked': '0'},
#      {'asset': 'UNI', 'free': '0', 'locked': '0'},
#      {'asset': 'USDT', 'free': '0.9941', 'locked': '0'},
#      {'asset': 'VET', 'free': '0', 'locked': '0'},
#      {'asset': 'XEC', 'free': '0', 'locked': '0'},
#      {'asset': 'XRP', 'free': '0', 'locked': '0'},
#      {'asset': 'XTZ', 'free': '0', 'locked': '0'},
#      {'asset': 'YFII', 'free': '0', 'locked': '0'}]}},
#   {'type': 'spot',
#    'updateTime': 1663718399000,
#    'data': {'totalAssetOfBtc': '0.00186303',
#     'balances': [{'asset': 'ADA', 'free': '0', 'locked': '0'},
#      {'asset': 'AUDIO', 'free': '0', 'locked': '0'},
#      {'asset': 'AXS', 'free': '0', 'locked': '0'},
#      {'asset': 'BAT', 'free': '0', 'locked': '0'},
#      {'asset': 'BCH', 'free': '0', 'locked': '0'},
#      {'asset': 'BNB', 'free': '0.00066492', 'locked': '0'},
#      {'asset': 'BTC', 'free': '0', 'locked': '0'},
#      {'asset': 'BURGER', 'free': '0', 'locked': '0'},
#      {'asset': 'BUSD', 'free': '34', 'locked': '0'},
#      {'asset': 'C98', 'free': '0', 'locked': '0'},
#      {'asset': 'CFX', 'free': '0', 'locked': '0'},
#      {'asset': 'ETH', 'free': '0', 'locked': '0'},
#      {'asset': 'GALA', 'free': '0', 'locked': '0'},
#      {'asset': 'HBAR', 'free': '0', 'locked': '0'},
#      {'asset': 'LDMANA', 'free': '0', 'locked': '0'},
#      {'asset': 'LTC', 'free': '0', 'locked': '0'},
#      {'asset': 'MANA', 'free': '0', 'locked': '0'},
#      {'asset': 'MATIC', 'free': '0', 'locked': '0'},
#      {'asset': 'MIR', 'free': '0', 'locked': '0'},
#      {'asset': 'RNDR', 'free': '0', 'locked': '0'},
#      {'asset': 'RUNE', 'free': '0', 'locked': '0'},
#      {'asset': 'SHIB', 'free': '0', 'locked': '0'},
#      {'asset': 'SOL', 'free': '0', 'locked': '0'},
#      {'asset': 'SOLO', 'free': '0.37104326', 'locked': '0'},
#      {'asset': 'TRX', 'free': '0', 'locked': '0'},
#      {'asset': 'UNI', 'free': '0', 'locked': '0'},
#      {'asset': 'USDT', 'free': '0.9941', 'locked': '0'},
#      {'asset': 'VET', 'free': '0', 'locked': '0'},
#      {'asset': 'XEC', 'free': '0', 'locked': '0'},
#      {'asset': 'XRP', 'free': '0', 'locked': '0'},
#      {'asset': 'XTZ', 'free': '0', 'locked': '0'},
#      {'asset': 'YFII', 'free': '0', 'locked': '0'}]}}]}

# %%
snap = pd.json_normalize(snap["snapshotVos"])
snap
# Out:
#    type     updateTime data.totalAssetOfBtc  \
# 0  spot  1663199999000           0.00595454
# 1  spot  1663286399000           0.00611443
# 2  spot  1663372799000           0.00001045
# 3  spot  1663459199000           0.00001045
# 4  spot  1663545599000           0.00315212
# 5  spot  1663631999000           0.00313094
# 6  spot  1663718399000           0.00186303
#
#                                        data.balances
# 0  [{'asset': 'ADA', 'free': '0', 'locked': '0'},...
# 1  [{'asset': 'ADA', 'free': '0', 'locked': '0'},...
# 2  [{'asset': 'ADA', 'free': '0', 'locked': '0'},...
# 3  [{'asset': 'ADA', 'free': '0', 'locked': '0'},...
# 4  [{'asset': 'ADA', 'free': '0', 'locked': '0'},...
# 5  [{'asset': 'ADA', 'free': '0', 'locked': '0'},...
# 6  [{'asset': 'ADA', 'free': '0', 'locked': '0'},...

# %%
snap.updateTime = pd.to_datetime(snap["updateTime"], unit = "ms")

# %%
snap
# Out:
#    type          updateTime data.totalAssetOfBtc  \
# 0  spot 2022-09-14 23:59:59           0.00595454
# 1  spot 2022-09-15 23:59:59           0.00611443
# 2  spot 2022-09-16 23:59:59           0.00001045
# 3  spot 2022-09-17 23:59:59           0.00001045
# 4  spot 2022-09-18 23:59:59           0.00315212
# 5  spot 2022-09-19 23:59:59           0.00313094
# 6  spot 2022-09-20 23:59:59           0.00186303
#
#                                        data.balances
# 0  [{'asset': 'ADA', 'free': '0', 'locked': '0'},...
# 1  [{'asset': 'ADA', 'free': '0', 'locked': '0'},...
# 2  [{'asset': 'ADA', 'free': '0', 'locked': '0'},...
# 3  [{'asset': 'ADA', 'free': '0', 'locked': '0'},...
# 4  [{'asset': 'ADA', 'free': '0', 'locked': '0'},...
# 5  [{'asset': 'ADA', 'free': '0', 'locked': '0'},...
# 6  [{'asset': 'ADA', 'free': '0', 'locked': '0'},...

# %%
snap["data.balances"][0]
# Out:
# [{'asset': 'ADA', 'free': '0', 'locked': '0'},
#  {'asset': 'AUDIO', 'free': '0', 'locked': '0'},
#  {'asset': 'AXS', 'free': '0', 'locked': '0'},
#  {'asset': 'BAT', 'free': '0', 'locked': '0'},
#  {'asset': 'BCH', 'free': '0', 'locked': '0'},
#  {'asset': 'BNB', 'free': '0.00075305', 'locked': '0'},
#  {'asset': 'BTC', 'free': '0', 'locked': '0'},
#  {'asset': 'BURGER', 'free': '0', 'locked': '0'},
#  {'asset': 'BUSD', 'free': '0', 'locked': '0'},
#  {'asset': 'C98', 'free': '0', 'locked': '0'},
#  {'asset': 'CFX', 'free': '0', 'locked': '0'},
#  {'asset': 'ETH', 'free': '0', 'locked': '0'},
#  {'asset': 'GALA', 'free': '0', 'locked': '0'},
#  {'asset': 'HBAR', 'free': '0', 'locked': '0'},
#  {'asset': 'LDMANA', 'free': '0', 'locked': '0'},
#  {'asset': 'LTC', 'free': '0', 'locked': '0'},
#  {'asset': 'MANA', 'free': '0', 'locked': '0'},
#  {'asset': 'MATIC', 'free': '0', 'locked': '0'},
#  {'asset': 'MIR', 'free': '0', 'locked': '0'},
#  {'asset': 'RNDR', 'free': '0', 'locked': '0'},
#  {'asset': 'RUNE', 'free': '0', 'locked': '0'},
#  {'asset': 'SHIB', 'free': '0', 'locked': '0'},
#  {'asset': 'SOL', 'free': '0', 'locked': '0'},
#  {'asset': 'SOLO', 'free': '0.37104326', 'locked': '0'},
#  {'asset': 'TRX', 'free': '0', 'locked': '0'},
#  {'asset': 'UNI', 'free': '0', 'locked': '0'},
#  {'asset': 'USDT', 'free': '120.25355361', 'locked': '0'},
#  {'asset': 'VET', 'free': '0', 'locked': '0'},
#  {'asset': 'XEC', 'free': '0', 'locked': '0'},
#  {'asset': 'XRP', 'free': '0', 'locked': '0'},
#  {'asset': 'XTZ', 'free': '0', 'locked': '0'},
#  {'asset': 'YFII', 'free': '0', 'locked': '0'}]

# %%
client.get_exchange_info()["rateLimits"] # API Limits
# Out:
# [{'rateLimitType': 'REQUEST_WEIGHT',
#   'interval': 'MINUTE',
#   'intervalNum': 1,
#   'limit': 1200},
#  {'rateLimitType': 'ORDERS',
#   'interval': 'SECOND',
#   'intervalNum': 10,
#   'limit': 50},
#  {'rateLimitType': 'ORDERS',
#   'interval': 'DAY',
#   'intervalNum': 1,
#   'limit': 160000},
#  {'rateLimitType': 'RAW_REQUESTS',
#   'interval': 'MINUTE',
#   'intervalNum': 5,
#   'limit': 6100}]

# %%
client.get_all_coins_info() # asset/coin Info
# Out:
# [{'coin': 'AGLD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Adventure Gold',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'AGLD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '10',
#     'withdrawMin': '20',
#     'withdrawMax': '9999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'STPT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Standard Tokenization Protocol',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'STPT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '75',
#     'withdrawMin': '150',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'MXN',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Mexican Peso',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'MXN',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False}]},
#  {'coin': 'UGX',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Uganda Shilling',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'UGX',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False}]},
#  {'coin': 'RENBTC',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'renBTC',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BSC',
#     'coin': 'RENBTC',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'Deposit for this token is not supported, please try other networks.',
#     'withdrawDesc': 'Withdrawal for this token is not supported, please try other networks.',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.0000042',
#     'withdrawMin': '0.0000084',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'ETH',
#     'coin': 'RENBTC',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'The wallet is currently undergoing maintenance. Your funds in transit are safe once confirmed on the blockchain and will be credited shortly after deposits have resumed.',
#     'withdrawDesc': 'The wallet is currently undergoing maintenance. Withdrawals for this asset will be resumed shortly.',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.00017',
#     'withdrawMin': '0.00034',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'GLM',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Golem',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'GLM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '11',
#     'withdrawMin': '22',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'RAY',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Raydium',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'SOL',
#     'coin': 'RAY',
#     'withdrawIntegerMultiple': '0.000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The Solana blockchain will retain 0.00203928 SOL for your first token deposit. The following deposits will not be charge for any fee.',
#     'specialWithdrawTips': '',
#     'name': 'Solana',
#     'resetAddressStatus': False,
#     'addressRegex': '^[1-9A-HJ-NP-Za-km-z]{32,44}$',
#     'addressRule': 'ADDRESS',
#     'memoRegex': '',
#     'withdrawFee': '0.46',
#     'withdrawMin': '0.92',
#     'withdrawMax': '9999999',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'NEAR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'NEAR Protocol',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'NEAR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.021',
#     'withdrawMin': '0.042',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'NEAR',
#     'coin': 'NEAR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'NEAR Protocol',
#     'resetAddressStatus': False,
#     'addressRegex': '^[a-z0-9_-]{1}[a-z0-9_.-]{0,62}[a-z0-9_-]{1}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.01',
#     'withdrawMin': '0.2',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 5,
#     'sameAddress': False,
#     'estimatedArrivalTime': 20,
#     'busy': False,
#     'country': 'BINANCE_BAHRAIN_BSC'},
#    {'network': 'BNB',
#     'coin': 'NEAR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Both a MEMO and an Address are required to successfully deposit your BEP2 tokens to Binance.',
#     'name': 'BNB Beacon Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'addressRule': '',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.035',
#     'withdrawMin': '0.07',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'AUDIO',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Audius',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'AUDIO',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '14',
#     'withdrawMin': '28',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'HNT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Helium',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'HNT',
#     'coin': 'HNT',
#     'withdrawIntegerMultiple': '0.01',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Helium',
#     'resetAddressStatus': False,
#     'addressRegex': '^(1)[0-9A-za-z]{50}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.05',
#     'withdrawMin': '1.5',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'ADADOWN',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'ADADOWN',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETF',
#     'coin': 'ADADOWN',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'ETF',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False}]},
#  {'coin': 'CDT',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'Blox',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'CDT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'The wallet is currently undergoing maintenance. Your funds in transit are safe once confirmed on the blockchain and will be credited shortly after deposits have resumed.',
#     'withdrawDesc': 'The wallet is currently undergoing maintenance. Withdrawals for this asset will be resumed shortly.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '138',
#     'withdrawMin': '276',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'SPARTA',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'Spartan Protocol',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BSC',
#     'coin': 'SPARTA',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'Deposit for this token is not supported, please try other networks.',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will potentially lose your assets if the chosen platform does not support refund of wrongfully deposited assets. Please note that you are withdrawing SPARTAv2 which is subject to a fee burn. For more information, please refer to: ##https://spartanprotocol.medium.com/spartav2-token-fee-burn-97e5441da98e##',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '2',
#     'withdrawMin': '4',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'SUSD',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'sUSD',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'SUSD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'The wallet is currently undergoing maintenance. Your funds in transit are safe once confirmed on the blockchain and will be credited shortly after deposits have resumed.',
#     'withdrawDesc': 'The wallet is currently undergoing maintenance. Withdrawals for this asset will be resumed shortly.',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '15',
#     'withdrawMin': '30',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'FARM',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Harvest Finance',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'FARM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.0021',
#     'withdrawMin': '0.0042',
#     'withdrawMax': '9999999',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'ETH',
#     'coin': 'FARM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.084',
#     'withdrawMin': '0.17',
#     'withdrawMax': '9999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'SDG',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Sudanese Pound',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'SDG',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False}]},
#  {'coin': 'XNO',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Nano',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'NANO',
#     'coin': 'XNO',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Minimum deposit amount: 0.001 XNO. Any deposits less than the minimum will not be credited or refunded.',
#     'specialWithdrawTips': '',
#     'name': 'NANO',
#     'resetAddressStatus': False,
#     'addressRegex': '^(xrb_|nano_)[13456789abcdefghijkmnopqrstuwxyz]{60}',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.03',
#     'withdrawMin': '0.06',
#     'withdrawMax': '10000000000',
#     'depositDust': '0.001',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 10,
#     'busy': False}]},
#  {'coin': 'AION',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'AION',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'AION',
#     'coin': 'AION',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Aion',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{64}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.1',
#     'withdrawMin': '0.2',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 60,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 15,
#     'busy': False},
#    {'network': 'ETH',
#     'coin': 'AION',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'The wallet is currently undergoing maintenance. Withdrawals for this asset will be resumed shortly.',
#     'specialTips': 'This deposit address supports ERC20 tokens. We will automatically convert your tokens to the Mainnet.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '79',
#     'withdrawMin': '158',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'DGB',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'DigiByte',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'DGB',
#     'coin': 'DGB',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'DigiByte',
#     'resetAddressStatus': False,
#     'addressRegex': '^[DS][a-km-zA-HJ-NP-Z1-9]{25,34}$|^(dgb1)[0-9A-Za-z]{39,59}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.2',
#     'withdrawMin': '0.4',
#     'withdrawMax': '10000000000',
#     'minConfirm': 10,
#     'unLockConfirm': 50,
#     'sameAddress': False,
#     'estimatedArrivalTime': 10,
#     'busy': False,
#     'country': 'BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'ZRX',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': '0x',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'ZRX',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '12',
#     'withdrawMin': '24',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'BCD',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'Bitcoin Diamond',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BCD',
#     'coin': 'BCD',
#     'withdrawIntegerMultiple': '0.000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'Deposit for this token is not supported, please try other networks.',
#     'withdrawDesc': 'Withdrawal for this token is not supported, please try other networks.',
#     'specialTips': '',
#     'name': 'Bitcoin Diamond',
#     'resetAddressStatus': False,
#     'addressRegex': '^[13][a-km-zA-HJ-NP-Z1-9]{25,34}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.01',
#     'withdrawMin': '0.02',
#     'withdrawMax': '10000000000',
#     'minConfirm': 6,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 60,
#     'busy': False,
#     'country': 'BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'EASY',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'EasyFi',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BSC',
#     'coin': 'EASY',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'The wallet is currently undergoing maintenance. Your funds in transit are safe once confirmed on the blockchain and will be credited shortly after deposits have resumed.',
#     'withdrawDesc': 'The wallet is currently undergoing maintenance. Withdrawals for this asset will be resumed shortly.',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.014',
#     'withdrawMin': '0.028',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'ETH',
#     'coin': 'EASY',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'The wallet is currently undergoing maintenance. Your funds in transit are safe once confirmed on the blockchain and will be credited shortly after deposits have resumed.',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.58',
#     'withdrawMin': '1.16',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'SANTOS',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Santos FC Fan Token',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'SANTOS',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.0068',
#     'withdrawMin': '0.014',
#     'withdrawMax': '9999999',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'WING',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Wing Token',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ONT',
#     'coin': 'WING',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ontology',
#     'resetAddressStatus': False,
#     'addressRegex': '^(A)[A-Za-z0-9]{33}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.0012',
#     'withdrawMin': '0.0024',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 5,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'WNXM',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Wrapped NXM',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'WNXM',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.22',
#     'withdrawMin': '0.44',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'BCH',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Bitcoin Cash',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.00071',
#     'withdrawMin': '0.0014',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'BCH',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Bitcoin Cash',
#     'resetAddressStatus': False,
#     'addressRegex': '^[13][a-km-zA-HJ-NP-Z1-9]{25,34}$|^[0-9A-Za-z]{42,42}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.0008',
#     'withdrawMin': '0.002',
#     'withdrawMax': '10000000000',
#     'minConfirm': 2,
#     'unLockConfirm': 6,
#     'sameAddress': False,
#     'estimatedArrivalTime': 35,
#     'busy': False,
#     'country': 'BINANCE_BAHRAIN_BSC'},
#    {'network': 'BNB',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please enter both MEMO and Address data, which are required to deposit BCH BEP2 tokens to your Binance account.',
#     'name': 'BNB Beacon Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'addressRule': '',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.0012',
#     'withdrawMin': '0.0024',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'ETH',
#     'coin': 'BCH',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': 'The wallet is currently undergoing maintenance. Withdrawals for this asset will be resumed shortly.',
#     'specialTips': 'This deposit address supports ERC20 BBCH tokens. Please ensure your destination address supports BBCH tokens under the contract address ending in 65f1b.',
#     'specialWithdrawTips': 'The network you have selected is ERC20-BBCH. Please ensure that the withdrawal address supports the ERC20-BBCH. You will potentially lose your assets if the chosen platform does not support refund of wrongfully deposited assets.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.029',
#     'withdrawMin': '0.058',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'JST',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'JUST',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'JST',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '3.19',
#     'withdrawMin': '6.38',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'TRX',
#     'coin': 'JST',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Tron (TRC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^T[1-9A-HJ-NP-Za-km-z]{33}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '50',
#     'withdrawMin': '100',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'ADAUP',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'ADAUP',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETF',
#     'coin': 'ADAUP',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'ETF',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False}]},
#  {'coin': 'HOT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Holo',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'HOT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Holo (ticker: HOT). Please ensure you are depositing Holo (HOT) tokens under the contract address ending in 526e2.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '1599',
#     'withdrawMin': '3198',
#     'withdrawMax': '9900000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'XOF',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'West African CFA',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'XOF',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False}]},
#  {'coin': 'GMT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Green Metaverse Token',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'GMT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.13',
#     'withdrawMin': '0.26',
#     'withdrawMax': '9999999',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'ETH',
#     'coin': 'GMT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '5.25',
#     'withdrawMin': '10',
#     'withdrawMax': '1000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'SOL',
#     'coin': 'GMT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Solana',
#     'resetAddressStatus': False,
#     'addressRegex': '^[1-9A-HJ-NP-Za-km-z]{32,44}$',
#     'addressRule': 'ADDRESS',
#     'memoRegex': '',
#     'withdrawFee': '0.41',
#     'withdrawMin': '0.82',
#     'withdrawMax': '1000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'AR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Arweave',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'AR',
#     'coin': 'AR',
#     'withdrawIntegerMultiple': '0.00001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Arweave',
#     'resetAddressStatus': False,
#     'addressRegex': '^[0-9a-z-A-Z\\-\\_]{43}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.03',
#     'withdrawMin': '0.1',
#     'withdrawMax': '9999999',
#     'minConfirm': 20,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 40,
#     'busy': False,
#     'country': ''}]},
#  {'coin': 'IRIS',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'IRISnet',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'IRIS',
#     'coin': 'IRIS',
#     'withdrawIntegerMultiple': '0.000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Both a MEMO and an Address are required to successfully deposit your IRIS to Binance',
#     'name': 'IRISnet',
#     'resetAddressStatus': False,
#     'addressRegex': '^(iaa1)[0-9a-z]{38}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '1',
#     'withdrawMin': '2',
#     'withdrawMax': '10000000000',
#     'minConfirm': 10,
#     'unLockConfirm': 15,
#     'sameAddress': True,
#     'estimatedArrivalTime': 5,
#     'busy': False}]},
#  {'coin': 'BCX',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'BitcoinX',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BCX',
#     'coin': 'BCX',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'Sorry, we do not support deposits for this asset.',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'BitcoinX',
#     'resetAddressStatus': False,
#     'addressRegex': '^(X)[0-9A-za-z]{33}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.5',
#     'withdrawMin': '0.5',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 2,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False}]},
#  {'coin': 'SEK',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'Swedish Kroner',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'SEK',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'The wallet is currently undergoing maintenance. Your funds in transit are safe once confirmed on the blockchain and will be credited shortly after deposits have resumed.',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False}]},
#  {'coin': 'TRIG',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'Triggers',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'TRIG',
#     'coin': 'TRIG',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'Sorry, but this asset has been delisted. We cannot process deposits for this asset.',
#     'withdrawDesc': 'We have disabled withdrawals as our systems are currently undergoing maintenance.',
#     'specialTips': '',
#     'name': 'Triggers',
#     'resetAddressStatus': False,
#     'addressRegex': '^[13][a-km-zA-HJ-NP-Z1-9]{25,34}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '50',
#     'withdrawMin': '51',
#     'withdrawMax': '10000000000',
#     'minConfirm': 2,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False}]},
#  {'coin': 'RCN',
#   'depositAllEnable': False,
#   'withdrawAllEnable': True,
#   'name': 'Ripio Credit Network',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'RCN',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'The wallet is currently undergoing maintenance. Your funds in transit are safe once confirmed on the blockchain and will be credited shortly after deposits have resumed.',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Ripio Credit Network. Please ensure you are depositing Ripio Credit Network (RCN) tokens under the contract address ending in 375a6.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '925',
#     'withdrawMin': '1850',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'COVER',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': 'COVER Protocol',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETH',
#     'coin': 'COVER',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
# ...
#     'withdrawMin': '68',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'FIS',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Stafi',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'FIS',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.25',
#     'withdrawMin': '0.5',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'ETH',
#     'coin': 'FIS',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '10',
#     'withdrawMin': '20',
#     'withdrawMax': '9900000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'BAR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'FC Barcelona Fan Token BAR',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'CHZ',
#     'coin': 'BAR',
#     'withdrawIntegerMultiple': '1',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'Only CHZ network withdrawals supported. Withdrawing to an address that is not a CHZ network address will result the LOSS of your funds.',
#     'name': 'Chiliz Chain (CHZ)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '1',
#     'withdrawMax': '9999999',
#     'minConfirm': 15,
#     'unLockConfirm': 30,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': ''}]},
#  {'coin': 'RAD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Radicle',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'RAD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '1.67',
#     'withdrawMin': '3.34',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'BAT',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Basic Attention Token',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'BAT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Basic Attention Token. Please ensure you are depositing Basic Attention Token (BAT) tokens under the contract address ending in 9766e.',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.27',
#     'withdrawMin': '0.54',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'BNB',
#     'coin': 'BAT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Basic Attention Token (BAT). Both a MEMO and an Address are required to successfully deposit your BEP2 tokens to Binance.',
#     'name': 'BNB Beacon Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'addressRule': '',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '0.45',
#     'withdrawMin': '0.9',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'ETH',
#     'coin': 'BAT',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'The name of this asset is Basic Attention Token. Please ensure you are depositing Basic Attention Token (BAT) tokens under the contract address ending in 887ef.',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '10',
#     'withdrawMin': '20',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'VRAB',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Verasity',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'BNB',
#     'coin': 'VRAB',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please enter both MEMO and Address data, which are required to deposit VRAB BEP2 tokens to your Binance account.',
#     'name': 'BNB Beacon Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'addressRule': '',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '100',
#     'withdrawMin': '200',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'ETH',
#     'coin': 'VRAB',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': False,
#     'withdrawEnable': True,
#     'depositDesc': 'The wallet is currently undergoing maintenance. Your funds in transit are safe once confirmed on the blockchain and will be credited shortly after deposits have resumed.',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '300',
#     'withdrawMin': '600',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'AKRO',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Akropolis',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'ETH',
#     'coin': 'AKRO',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '806',
#     'withdrawMin': '1612',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]},
#  {'coin': 'NZD',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'New Zealand Dollar',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': True,
#   'trading': False,
#   'networkList': [{'network': 'FIAT_MONEY',
#     'coin': 'NZD',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'FIAT',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '10000000000',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False}]},
#  {'coin': 'MOVR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Moonriver',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'MOVR',
#     'coin': 'MOVR',
#     'withdrawIntegerMultiple': '0.00001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': '',
#     'name': 'Moonriver',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.003',
#     'withdrawMin': '0.006',
#     'withdrawMax': '9999999',
#     'minConfirm': 30,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 10,
#     'busy': False}]},
#  {'coin': 'XMR',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'Monero',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'XMR',
#     'coin': 'XMR',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Monero',
#     'resetAddressStatus': False,
#     'addressRegex': '^[48][a-zA-Z|\\d]{94}([a-zA-Z|\\d]{11})?$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.0001',
#     'withdrawMin': '0.0002',
#     'withdrawMax': '10000000000',
#     'minConfirm': 3,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 10,
#     'busy': False,
#     'country': 'BINANCE_BAHRAIN_BSC'}]},
#  {'coin': '1INCHDOWN',
#   'depositAllEnable': False,
#   'withdrawAllEnable': False,
#   'name': '1INCHDOWN',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': False,
#   'networkList': [{'network': 'ETF',
#     'coin': '1INCHDOWN',
#     'withdrawIntegerMultiple': '0',
#     'isDefault': True,
#     'depositEnable': False,
#     'withdrawEnable': False,
#     'depositDesc': 'Not support deposit',
#     'withdrawDesc': 'Not support withdrawal',
#     'specialTips': '',
#     'name': 'ETF',
#     'resetAddressStatus': False,
#     'addressRegex': '',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0',
#     'withdrawMin': '0',
#     'withdrawMax': '9999999999.99999999',
#     'minConfirm': 0,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False}]},
#  {'coin': 'COTI',
#   'depositAllEnable': True,
#   'withdrawAllEnable': True,
#   'name': 'COTI',
#   'free': '0',
#   'locked': '0',
#   'freeze': '0',
#   'withdrawing': '0',
#   'ipoing': '0',
#   'ipoable': '0',
#   'storage': '0',
#   'isLegalMoney': False,
#   'trading': True,
#   'networkList': [{'network': 'BSC',
#     'coin': 'COTI',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'specialWithdrawTips': 'The network you have selected is BSC. Please ensure that the withdrawal address supports the Binance Smart Chain network. You will lose your assets if the chosen platform does not support retrievals.',
#     'name': 'BNB Smart Chain (BEP20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '0.87',
#     'withdrawMin': '1.74',
#     'withdrawMax': '10000000000',
#     'minConfirm': 15,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'BNB',
#     'coin': 'COTI',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': False,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': 'Please enter both MEMO and Address data, which are required to deposit COTI BEP2 tokens to your Binance account.',
#     'name': 'BNB Beacon Chain (BEP2)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(bnb1)[0-9a-z]{38}$',
#     'addressRule': '',
#     'memoRegex': '^[0-9A-Za-z\\-_]{1,120}$',
#     'withdrawFee': '1.44',
#     'withdrawMin': '2.88',
#     'withdrawMax': '10000000000',
#     'minConfirm': 1,
#     'unLockConfirm': 0,
#     'sameAddress': True,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'},
#    {'network': 'ETH',
#     'coin': 'COTI',
#     'withdrawIntegerMultiple': '0.00000001',
#     'isDefault': True,
#     'depositEnable': True,
#     'withdrawEnable': True,
#     'depositDesc': '',
#     'withdrawDesc': '',
#     'specialTips': '',
#     'name': 'Ethereum (ERC20)',
#     'resetAddressStatus': False,
#     'addressRegex': '^(0x)[0-9A-Fa-f]{40}$',
#     'addressRule': '',
#     'memoRegex': '',
#     'withdrawFee': '34',
#     'withdrawMin': '68',
#     'withdrawMax': '10000000000',
#     'minConfirm': 12,
#     'unLockConfirm': 0,
#     'sameAddress': False,
#     'estimatedArrivalTime': 5,
#     'busy': False,
#     'country': 'AE,BINANCE_BAHRAIN_BSC'}]}]

# %%
coins = pd.DataFrame(client.get_all_coins_info()) # asset/coin Info
coins
# Out:
#           coin  depositAllEnable  withdrawAllEnable  \
# 0         AGLD              True               True
# 1         STPT              True               True
# 2          MXN              True               True
# 3          UGX              True               True
# 4       RENBTC             False              False
# ..         ...               ...                ...
# 589        NZD              True               True
# 590       MOVR              True               True
# 591        XMR              True               True
# 592  1INCHDOWN             False              False
# 593       COTI              True               True
#
#                                name free locked freeze withdrawing ipoing  \
# 0                    Adventure Gold    0      0      0           0      0
# 1    Standard Tokenization Protocol    0      0      0           0      0
# 2                      Mexican Peso    0      0      0           0      0
# 3                   Uganda Shilling    0      0      0           0      0
# 4                            renBTC    0      0      0           0      0
# ..                              ...  ...    ...    ...         ...    ...
# 589              New Zealand Dollar    0      0      0           0      0
# 590                       Moonriver    0      0      0           0      0
# 591                          Monero    0      0      0           0      0
# 592                       1INCHDOWN    0      0      0           0      0
# 593                            COTI    0      0      0           0      0
#
#     ipoable storage  isLegalMoney  trading  \
# 0         0       0         False     True
# 1         0       0         False     True
# 2         0       0          True    False
# 3         0       0          True    False
# 4         0       0         False    False
# ..      ...     ...           ...      ...
# 589       0       0          True    False
# 590       0       0         False     True
# 591       0       0         False     True
# 592       0       0         False    False
# 593       0       0         False     True
#
#                                            networkList
# 0    [{'network': 'ETH', 'coin': 'AGLD', 'withdrawI...
# 1    [{'network': 'ETH', 'coin': 'STPT', 'withdrawI...
# 2    [{'network': 'FIAT_MONEY', 'coin': 'MXN', 'wit...
# 3    [{'network': 'FIAT_MONEY', 'coin': 'UGX', 'wit...
# 4    [{'network': 'BSC', 'coin': 'RENBTC', 'withdra...
# ..                                                 ...
# 589  [{'network': 'FIAT_MONEY', 'coin': 'NZD', 'wit...
# 590  [{'network': 'MOVR', 'coin': 'MOVR', 'withdraw...
# 591  [{'network': 'XMR', 'coin': 'XMR', 'withdrawIn...
# 592  [{'network': 'ETF', 'coin': '1INCHDOWN', 'with...
# 593  [{'network': 'BSC', 'coin': 'COTI', 'withdrawI...
#
# [594 rows x 14 columns]

# %%
coins.loc[coins.coin == "SOL"]
# Out:
#     coin  depositAllEnable  withdrawAllEnable    name free locked freeze  \
# 225  SOL              True               True  Solana    0      0      0
#
#     withdrawing ipoing ipoable storage  isLegalMoney  trading  \
# 225           0      0       0       0         False     True
#
#                                            networkList
# 225  [{'network': 'BSC', 'coin': 'SOL', 'withdrawIn...

# %%
coins.loc[coins.coin == "EUR"]
# Out:
#     coin  depositAllEnable  withdrawAllEnable  name free locked freeze  \
# 271  EUR              True               True  Euro    0      0      0
#
#     withdrawing ipoing ipoable storage  isLegalMoney  trading  \
# 271           0      0       0       0          True     True
#
#                                            networkList
# 271  [{'network': 'FIAT_MONEY', 'coin': 'EUR', 'wit...

# %%
client.get_trade_fee(symbol = "BTCUSDT")
# Out:
# [{'symbol': 'BTCUSDT', 'makerCommission': '0', 'takerCommission': '0'}]

# %%
client.get_trade_fee(symbol = "BTCEUR")
# Out:
# [{'symbol': 'BTCEUR', 'makerCommission': '0', 'takerCommission': '0'}]

# %%
client.get_trade_fee(symbol = "BUSDUSDT") # zero commissions for stable coin pairs
# Out:
# [{'symbol': 'BUSDUSDT', 'makerCommission': '0', 'takerCommission': '0'}]

# %%
client.get_symbol_info(symbol = "BTCEUR") # information on symbol / pair
# Out:
# {'symbol': 'BTCEUR',
#  'status': 'TRADING',
#  'baseAsset': 'BTC',
#  'baseAssetPrecision': 8,
#  'quoteAsset': 'EUR',
#  'quotePrecision': 8,
#  'quoteAssetPrecision': 8,
#  'baseCommissionPrecision': 8,
#  'quoteCommissionPrecision': 8,
#  'orderTypes': ['LIMIT',
#   'LIMIT_MAKER',
#   'MARKET',
#   'STOP_LOSS_LIMIT',
#   'TAKE_PROFIT_LIMIT'],
#  'icebergAllowed': True,
#  'ocoAllowed': True,
#  'quoteOrderQtyMarketAllowed': True,
#  'allowTrailingStop': True,
#  'cancelReplaceAllowed': True,
#  'isSpotTradingAllowed': True,
#  'isMarginTradingAllowed': False,
#  'filters': [{'filterType': 'PRICE_FILTER',
#    'minPrice': '0.01000000',
#    'maxPrice': '1000000.00000000',
#    'tickSize': '0.01000000'},
#   {'filterType': 'PERCENT_PRICE',
#    'multiplierUp': '5',
#    'multiplierDown': '0.2',
#    'avgPriceMins': 5},
#   {'filterType': 'LOT_SIZE',
#    'minQty': '0.00001000',
#    'maxQty': '9000.00000000',
#    'stepSize': '0.00001000'},
#   {'filterType': 'MIN_NOTIONAL',
#    'minNotional': '10.00000000',
#    'applyToMarket': True,
#    'avgPriceMins': 5},
#   {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#   {'filterType': 'MARKET_LOT_SIZE',
#    'minQty': '0.00000000',
#    'maxQty': '101.07306551',
#    'stepSize': '0.00000000'},
#   {'filterType': 'TRAILING_DELTA',
#    'minTrailingAboveDelta': 10,
#    'maxTrailingAboveDelta': 2000,
#    'minTrailingBelowDelta': 10,
#    'maxTrailingBelowDelta': 2000},
#   {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': 200},
#   {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}],
#  'permissions': ['SPOT']}

# %% [markdown]
# ## Getting (current) Market Data

# %%
from binance.client import Client
import pandas as pd

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com")

# %% [markdown]
# __Current Prices__

# %%
client.get_symbol_ticker(symbol = "BTCUSDT") # current price for one symbol
# Out:
# {'symbol': 'BTCUSDT', 'price': '18995.68000000'}

# %%
float(client.get_symbol_ticker(symbol = "BTCEUR")["price"])
# Out:
# 19320.39

# %%
client.get_avg_price(symbol = "BTCUSDT") # current average price
# Out:
# {'mins': 5, 'price': '19015.12342002'}

# %%
# get current prices for all pairs
prices = client.get_all_tickers()
prices
# Out:
# [{'symbol': 'ETHBTC', 'price': '0.07026300'},
#  {'symbol': 'LTCBTC', 'price': '0.00281500'},
#  {'symbol': 'BNBBTC', 'price': '0.01406700'},
#  {'symbol': 'NEOBTC', 'price': '0.00044000'},
#  {'symbol': 'QTUMETH', 'price': '0.00215200'},
#  {'symbol': 'EOSETH', 'price': '0.00094400'},
#  {'symbol': 'SNTETH', 'price': '0.00002151'},
#  {'symbol': 'BNTETH', 'price': '0.00032500'},
#  {'symbol': 'BCCBTC', 'price': '0.07908100'},
#  {'symbol': 'GASBTC', 'price': '0.00012040'},
#  {'symbol': 'BNBETH', 'price': '0.20030000'},
#  {'symbol': 'BTCUSDT', 'price': '19033.65000000'},
#  {'symbol': 'ETHUSDT', 'price': '1337.27000000'},
#  {'symbol': 'HSRBTC', 'price': '0.00041400'},
#  {'symbol': 'OAXETH', 'price': '0.00017780'},
#  {'symbol': 'DNTETH', 'price': '0.00002801'},
#  {'symbol': 'MCOETH', 'price': '0.00577200'},
#  {'symbol': 'ICNETH', 'price': '0.00166300'},
#  {'symbol': 'MCOBTC', 'price': '0.00021140'},
#  {'symbol': 'WTCBTC', 'price': '0.00001420'},
#  {'symbol': 'WTCETH', 'price': '0.00023700'},
#  {'symbol': 'LRCBTC', 'price': '0.00001586'},
#  {'symbol': 'LRCETH', 'price': '0.00022575'},
#  {'symbol': 'QTUMBTC', 'price': '0.00015130'},
#  {'symbol': 'YOYOBTC', 'price': '0.00000008'},
#  {'symbol': 'OMGBTC', 'price': '0.00008980'},
#  {'symbol': 'OMGETH', 'price': '0.00128100'},
#  {'symbol': 'ZRXBTC', 'price': '0.00001421'},
#  {'symbol': 'ZRXETH', 'price': '0.00020120'},
#  {'symbol': 'STRATBTC', 'price': '0.00003085'},
#  {'symbol': 'STRATETH', 'price': '0.00105300'},
#  {'symbol': 'SNGLSBTC', 'price': '0.00000013'},
#  {'symbol': 'SNGLSETH', 'price': '0.00005306'},
#  {'symbol': 'BQXBTC', 'price': '0.00008703'},
#  {'symbol': 'BQXETH', 'price': '0.00126350'},
#  {'symbol': 'KNCBTC', 'price': '0.00006625'},
#  {'symbol': 'KNCETH', 'price': '0.00094560'},
#  {'symbol': 'FUNBTC', 'price': '0.00000029'},
#  {'symbol': 'FUNETH', 'price': '0.00000548'},
#  {'symbol': 'SNMBTC', 'price': '0.00001746'},
#  {'symbol': 'SNMETH', 'price': '0.00004986'},
#  {'symbol': 'NEOETH', 'price': '0.00626000'},
#  {'symbol': 'IOTABTC', 'price': '0.00001359'},
#  {'symbol': 'IOTAETH', 'price': '0.00019330'},
#  {'symbol': 'LINKBTC', 'price': '0.00037020'},
#  {'symbol': 'LINKETH', 'price': '0.00527100'},
#  {'symbol': 'XVGBTC', 'price': '0.00000015'},
#  {'symbol': 'XVGETH', 'price': '0.00000244'},
#  {'symbol': 'SALTBTC', 'price': '0.00004250'},
#  {'symbol': 'SALTETH', 'price': '0.00113800'},
#  {'symbol': 'MDABTC', 'price': '0.00000382'},
#  {'symbol': 'MDAETH', 'price': '0.00181150'},
#  {'symbol': 'MTLBTC', 'price': '0.00005650'},
#  {'symbol': 'MTLETH', 'price': '0.00080020'},
#  {'symbol': 'SUBBTC', 'price': '0.00000457'},
#  {'symbol': 'SUBETH', 'price': '0.00012334'},
#  {'symbol': 'EOSBTC', 'price': '0.00006640'},
#  {'symbol': 'SNTBTC', 'price': '0.00000151'},
#  {'symbol': 'ETCETH', 'price': '0.02179000'},
#  {'symbol': 'ETCBTC', 'price': '0.00153300'},
#  {'symbol': 'MTHBTC', 'price': '0.00000023'},
#  {'symbol': 'MTHETH', 'price': '0.00004135'},
#  {'symbol': 'ENGBTC', 'price': '0.00006200'},
#  {'symbol': 'ENGETH', 'price': '0.00186480'},
#  {'symbol': 'DNTBTC', 'price': '0.00000220'},
#  {'symbol': 'ZECBTC', 'price': '0.00287800'},
#  {'symbol': 'ZECETH', 'price': '0.04097000'},
#  {'symbol': 'BNTBTC', 'price': '0.00002288'},
#  {'symbol': 'ASTBTC', 'price': '0.00000796'},
#  {'symbol': 'ASTETH', 'price': '0.00006960'},
#  {'symbol': 'DASHBTC', 'price': '0.00216500'},
#  {'symbol': 'DASHETH', 'price': '0.03071000'},
#  {'symbol': 'OAXBTC', 'price': '0.00001607'},
#  {'symbol': 'ICNBTC', 'price': '0.00005742'},
#  {'symbol': 'BTGBTC', 'price': '0.00110100'},
#  {'symbol': 'BTGETH', 'price': '0.05274500'},
#  {'symbol': 'EVXBTC', 'price': '0.00000274'},
#  {'symbol': 'EVXETH', 'price': '0.00062490'},
#  {'symbol': 'REQBTC', 'price': '0.00000535'},
#  {'symbol': 'REQETH', 'price': '0.00004995'},
#  {'symbol': 'VIBBTC', 'price': '0.00000446'},
#  {'symbol': 'VIBETH', 'price': '0.00006355'},
#  {'symbol': 'HSRETH', 'price': '0.01247400'},
#  {'symbol': 'TRXBTC', 'price': '0.00000316'},
#  {'symbol': 'TRXETH', 'price': '0.00004500'},
#  {'symbol': 'POWRBTC', 'price': '0.00001007'},
#  {'symbol': 'POWRETH', 'price': '0.00014240'},
#  {'symbol': 'ARKBTC', 'price': '0.00001987'},
#  {'symbol': 'ARKETH', 'price': '0.00104600'},
#  {'symbol': 'YOYOETH', 'price': '0.00005828'},
#  {'symbol': 'XRPBTC', 'price': '0.00002154'},
#  {'symbol': 'XRPETH', 'price': '0.00030620'},
#  {'symbol': 'MODBTC', 'price': '0.00004280'},
#  {'symbol': 'MODETH', 'price': '0.00116700'},
#  {'symbol': 'ENJBTC', 'price': '0.00002493'},
#  {'symbol': 'ENJETH', 'price': '0.00035320'},
#  {'symbol': 'STORJBTC', 'price': '0.00002438'},
#  {'symbol': 'STORJETH', 'price': '0.00029910'},
#  {'symbol': 'BNBUSDT', 'price': '267.70000000'},
#  {'symbol': 'VENBNB', 'price': '0.14920000'},
#  {'symbol': 'YOYOBNB', 'price': '0.00059800'},
#  {'symbol': 'POWRBNB', 'price': '0.00385000'},
#  {'symbol': 'VENBTC', 'price': '0.00013928'},
#  {'symbol': 'VENETH', 'price': '0.00325194'},
#  {'symbol': 'KMDBTC', 'price': '0.00001348'},
#  {'symbol': 'KMDETH', 'price': '0.00020970'},
#  {'symbol': 'NULSBNB', 'price': '0.01257000'},
#  {'symbol': 'RCNBTC', 'price': '0.00000074'},
#  {'symbol': 'RCNETH', 'price': '0.00037604'},
#  {'symbol': 'RCNBNB', 'price': '0.00347300'},
#  {'symbol': 'NULSBTC', 'price': '0.00000985'},
#  {'symbol': 'NULSETH', 'price': '0.00051926'},
#  {'symbol': 'RDNBTC', 'price': '0.00000447'},
#  {'symbol': 'RDNETH', 'price': '0.00071530'},
#  {'symbol': 'RDNBNB', 'price': '0.00623000'},
#  {'symbol': 'XMRBTC', 'price': '0.00743400'},
#  {'symbol': 'XMRETH', 'price': '0.10595000'},
#  {'symbol': 'DLTBNB', 'price': '0.00240000'},
#  {'symbol': 'WTCBNB', 'price': '0.00180500'},
#  {'symbol': 'DLTBTC', 'price': '0.00000071'},
#  {'symbol': 'DLTETH', 'price': '0.00016807'},
#  {'symbol': 'AMBBTC', 'price': '0.00000110'},
#  {'symbol': 'AMBETH', 'price': '0.00004100'},
#  {'symbol': 'AMBBNB', 'price': '0.00068500'},
#  {'symbol': 'BCCETH', 'price': '2.47246000'},
#  {'symbol': 'BCCUSDT', 'price': '448.70000000'},
#  {'symbol': 'BCCBNB', 'price': '54.29000000'},
#  {'symbol': 'BATBTC', 'price': '0.00001584'},
#  {'symbol': 'BATETH', 'price': '0.00022580'},
#  {'symbol': 'BATBNB', 'price': '0.00183100'},
#  {'symbol': 'BCPTBTC', 'price': '0.00000048'},
#  {'symbol': 'BCPTETH', 'price': '0.00008181'},
#  {'symbol': 'BCPTBNB', 'price': '0.00116200'},
#  {'symbol': 'ARNBTC', 'price': '0.00000761'},
#  {'symbol': 'ARNETH', 'price': '0.00029362'},
#  {'symbol': 'GVTBTC', 'price': '0.00001792'},
#  {'symbol': 'GVTETH', 'price': '0.00384600'},
#  {'symbol': 'CDTBTC', 'price': '0.00000317'},
#  {'symbol': 'CDTETH', 'price': '0.00005119'},
#  {'symbol': 'GXSBTC', 'price': '0.00004581'},
#  {'symbol': 'GXSETH', 'price': '0.00062460'},
#  {'symbol': 'NEOUSDT', 'price': '8.36000000'},
#  {'symbol': 'NEOBNB', 'price': '0.03120000'},
#  {'symbol': 'POEBTC', 'price': '0.00000005'},
#  {'symbol': 'POEETH', 'price': '0.00000664'},
#  {'symbol': 'QSPBTC', 'price': '0.00000076'},
#  {'symbol': 'QSPETH', 'price': '0.00002249'},
#  {'symbol': 'QSPBNB', 'price': '0.00052350'},
#  {'symbol': 'BTSBTC', 'price': '0.00000074'},
#  {'symbol': 'BTSETH', 'price': '0.00009498'},
#  {'symbol': 'BTSBNB', 'price': '0.00144800'},
#  {'symbol': 'XZCBTC', 'price': '0.00013550'},
#  {'symbol': 'XZCETH', 'price': '0.00310000'},
#  {'symbol': 'XZCBNB', 'price': '0.26750000'},
#  {'symbol': 'LSKBTC', 'price': '0.00004896'},
#  {'symbol': 'LSKETH', 'price': '0.00069300'},
#  {'symbol': 'LSKBNB', 'price': '0.06494000'},
#  {'symbol': 'TNTBTC', 'price': '0.00000261'},
#  {'symbol': 'TNTETH', 'price': '0.00000920'},
#  {'symbol': 'FUELBTC', 'price': '0.00000026'},
#  {'symbol': 'FUELETH', 'price': '0.00002221'},
#  {'symbol': 'MANABTC', 'price': '0.00003738'},
#  {'symbol': 'MANAETH', 'price': '0.00053140'},
#  {'symbol': 'BCDBTC', 'price': '0.00001351'},
#  {'symbol': 'BCDETH', 'price': '0.00251000'},
#  {'symbol': 'DGDBTC', 'price': '0.00393100'},
#  {'symbol': 'DGDETH', 'price': '0.19260000'},
#  {'symbol': 'IOTABNB', 'price': '0.00096500'},
#  {'symbol': 'ADXBTC', 'price': '0.00000890'},
#  {'symbol': 'ADXETH', 'price': '0.00012680'},
#  {'symbol': 'ADXBNB', 'price': '0.00492900'},
#  {'symbol': 'ADABTC', 'price': '0.00002354'},
#  {'symbol': 'ADAETH', 'price': '0.00033470'},
#  {'symbol': 'PPTBTC', 'price': '0.00001855'},
#  {'symbol': 'PPTETH', 'price': '0.00141000'},
#  {'symbol': 'CMTBTC', 'price': '0.00000028'},
#  {'symbol': 'CMTETH', 'price': '0.00000625'},
#  {'symbol': 'CMTBNB', 'price': '0.00057700'},
#  {'symbol': 'XLMBTC', 'price': '0.00000603'},
#  {'symbol': 'XLMETH', 'price': '0.00008590'},
#  {'symbol': 'XLMBNB', 'price': '0.00042910'},
#  {'symbol': 'CNDBTC', 'price': '0.00000006'},
#  {'symbol': 'CNDETH', 'price': '0.00002599'},
#  {'symbol': 'CNDBNB', 'price': '0.00033990'},
#  {'symbol': 'LENDBTC', 'price': '0.00004512'},
#  {'symbol': 'LENDETH', 'price': '0.00137174'},
#  {'symbol': 'WABIBTC', 'price': '0.00001040'},
#  {'symbol': 'WABIETH', 'price': '0.00040308'},
#  {'symbol': 'WABIBNB', 'price': '0.00024130'},
#  {'symbol': 'LTCETH', 'price': '0.04009000'},
#  {'symbol': 'LTCUSDT', 'price': '53.57000000'},
#  {'symbol': 'LTCBNB', 'price': '0.20000000'},
#  {'symbol': 'TNBBTC', 'price': '0.00000007'},
#  {'symbol': 'TNBETH', 'price': '0.00000752'},
#  {'symbol': 'WAVESBTC', 'price': '0.00021240'},
#  {'symbol': 'WAVESETH', 'price': '0.00302200'},
#  {'symbol': 'WAVESBNB', 'price': '0.01513000'},
#  {'symbol': 'GTOBTC', 'price': '0.00000103'},
#  {'symbol': 'GTOETH', 'price': '0.00003197'},
#  {'symbol': 'GTOBNB', 'price': '0.00035200'},
#  {'symbol': 'ICXBTC', 'price': '0.00001269'},
#  {'symbol': 'ICXETH', 'price': '0.00017900'},
#  {'symbol': 'ICXBNB', 'price': '0.00465400'},
#  {'symbol': 'OSTBTC', 'price': '0.00000032'},
#  {'symbol': 'OSTETH', 'price': '0.00000225'},
#  {'symbol': 'OSTBNB', 'price': '0.00052500'},
#  {'symbol': 'ELFBTC', 'price': '0.00000682'},
#  {'symbol': 'ELFETH', 'price': '0.00009710'},
#  {'symbol': 'AIONBTC', 'price': '0.00000212'},
#  {'symbol': 'AIONETH', 'price': '0.00002645'},
#  {'symbol': 'AIONBNB', 'price': '0.00261300'},
#  {'symbol': 'NEBLBTC', 'price': '0.00009144'},
#  {'symbol': 'NEBLBNB', 'price': '0.01356000'},
#  {'symbol': 'BRDBTC', 'price': '0.00000127'},
#  {'symbol': 'BRDETH', 'price': '0.00001688'},
#  {'symbol': 'BRDBNB', 'price': '0.00247000'},
#  {'symbol': 'MCOBNB', 'price': '0.26837000'},
#  {'symbol': 'EDOBTC', 'price': '0.00005609'},
#  {'symbol': 'EDOETH', 'price': '0.00226600'},
#  {'symbol': 'WINGSBTC', 'price': '0.00001193'},
#  {'symbol': 'WINGSETH', 'price': '0.00033460'},
#  {'symbol': 'NAVBTC', 'price': '0.00000277'},
#  {'symbol': 'NAVETH', 'price': '0.00011870'},
#  {'symbol': 'NAVBNB', 'price': '0.00423700'},
#  {'symbol': 'LUNBTC', 'price': '0.00008510'},
#  {'symbol': 'LUNETH', 'price': '0.00489100'},
#  {'symbol': 'TRIGBTC', 'price': '0.00001980'},
#  {'symbol': 'TRIGETH', 'price': '0.00059400'},
#  {'symbol': 'TRIGBNB', 'price': '0.01218000'},
#  {'symbol': 'APPCBTC', 'price': '0.00000055'},
#  {'symbol': 'APPCETH', 'price': '0.00014600'},
#  {'symbol': 'APPCBNB', 'price': '0.00189100'},
#  {'symbol': 'VIBEBTC', 'price': '0.00000042'},
#  {'symbol': 'VIBEETH', 'price': '0.00005720'},
#  {'symbol': 'RLCBTC', 'price': '0.00006537'},
#  {'symbol': 'RLCETH', 'price': '0.00093000'},
#  {'symbol': 'RLCBNB', 'price': '0.03344000'},
#  {'symbol': 'INSBTC', 'price': '0.00000618'},
#  {'symbol': 'INSETH', 'price': '0.00050100'},
#  {'symbol': 'PIVXBTC', 'price': '0.00002301'},
#  {'symbol': 'PIVXBNB', 'price': '0.01660000'},
#  {'symbol': 'IOSTBTC', 'price': '0.00000064'},
#  {'symbol': 'IOSTETH', 'price': '0.00000905'},
#  {'symbol': 'CHATBTC', 'price': '0.00000195'},
#  {'symbol': 'CHATETH', 'price': '0.00006585'},
#  {'symbol': 'STEEMBTC', 'price': '0.00001119'},
#  {'symbol': 'STEEMETH', 'price': '0.00015910'},
#  {'symbol': 'STEEMBNB', 'price': '0.00448000'},
#  {'symbol': 'NANOBTC', 'price': '0.00006280'},
#  {'symbol': 'NANOETH', 'price': '0.00090500'},
#  {'symbol': 'NANOBNB', 'price': '0.05589000'},
#  {'symbol': 'VIABTC', 'price': '0.00000681'},
#  {'symbol': 'VIAETH', 'price': '0.00085600'},
#  {'symbol': 'VIABNB', 'price': '0.00958000'},
#  {'symbol': 'BLZBTC', 'price': '0.00000430'},
#  {'symbol': 'BLZETH', 'price': '0.00006120'},
#  {'symbol': 'BLZBNB', 'price': '0.00062190'},
#  {'symbol': 'AEBTC', 'price': '0.00000292'},
#  {'symbol': 'AEETH', 'price': '0.00021900'},
#  {'symbol': 'AEBNB', 'price': '0.00777000'},
#  {'symbol': 'RPXBTC', 'price': '0.00000224'},
#  {'symbol': 'RPXETH', 'price': '0.00005449'},
#  {'symbol': 'RPXBNB', 'price': '0.00145700'},
#  {'symbol': 'NCASHBTC', 'price': '0.00000005'},
#  {'symbol': 'NCASHETH', 'price': '0.00000013'},
#  {'symbol': 'NCASHBNB', 'price': '0.00006790'},
#  {'symbol': 'POABTC', 'price': '0.00000041'},
#  {'symbol': 'POAETH', 'price': '0.00004891'},
#  {'symbol': 'POABNB', 'price': '0.00092100'},
#  {'symbol': 'ZILBTC', 'price': '0.00000168'},
#  {'symbol': 'ZILETH', 'price': '0.00002398'},
#  {'symbol': 'ZILBNB', 'price': '0.00012000'},
#  {'symbol': 'ONTBTC', 'price': '0.00001167'},
#  {'symbol': 'ONTETH', 'price': '0.00016540'},
#  {'symbol': 'ONTBNB', 'price': '0.00246200'},
#  {'symbol': 'STORMBTC', 'price': '0.00000035'},
#  {'symbol': 'STORMETH', 'price': '0.00001398'},
#  {'symbol': 'STORMBNB', 'price': '0.00006550'},
#  {'symbol': 'QTUMBNB', 'price': '0.09597000'},
#  {'symbol': 'QTUMUSDT', 'price': '2.88100000'},
#  {'symbol': 'XEMBTC', 'price': '0.00000210'},
#  {'symbol': 'XEMETH', 'price': '0.00003593'},
#  {'symbol': 'XEMBNB', 'price': '0.00244100'},
#  {'symbol': 'WANBTC', 'price': '0.00000963'},
#  {'symbol': 'WANETH', 'price': '0.00013700'},
#  {'symbol': 'WANBNB', 'price': '0.00181000'},
#  {'symbol': 'WPRBTC', 'price': '0.00000027'},
#  {'symbol': 'WPRETH', 'price': '0.00004020'},
#  {'symbol': 'QLCBTC', 'price': '0.00000275'},
#  {'symbol': 'QLCETH', 'price': '0.00000603'},
#  {'symbol': 'SYSBTC', 'price': '0.00000923'},
#  {'symbol': 'SYSETH', 'price': '0.00011047'},
#  {'symbol': 'SYSBNB', 'price': '0.00163500'},
#  {'symbol': 'QLCBNB', 'price': '0.00092200'},
#  {'symbol': 'GRSBTC', 'price': '0.00001649'},
#  {'symbol': 'GRSETH', 'price': '0.00076455'},
#  {'symbol': 'ADAUSDT', 'price': '0.44800000'},
#  {'symbol': 'ADABNB', 'price': '0.00167400'},
#  {'symbol': 'CLOAKBTC', 'price': '0.00015550'},
#  {'symbol': 'CLOAKETH', 'price': '0.00414200'},
#  {'symbol': 'GNTBTC', 'price': '0.00000678'},
#  {'symbol': 'GNTETH', 'price': '0.00022071'},
#  {'symbol': 'GNTBNB', 'price': '0.00243900'},
#  {'symbol': 'LOOMBTC', 'price': '0.00000290'},
#  {'symbol': 'LOOMETH', 'price': '0.00004144'},
#  {'symbol': 'LOOMBNB', 'price': '0.00088500'},
#  {'symbol': 'XRPUSDT', 'price': '0.41000000'},
#  {'symbol': 'BCNBTC', 'price': '0.00000022'},
#  {'symbol': 'BCNETH', 'price': '0.00000707'},
#  {'symbol': 'BCNBNB', 'price': '0.00002000'},
#  {'symbol': 'REPBTC', 'price': '0.00037050'},
#  {'symbol': 'REPBNB', 'price': '0.44670000'},
#  {'symbol': 'BTCTUSD', 'price': '19018.68000000'},
#  {'symbol': 'TUSDBTC', 'price': '0.00025971'},
#  {'symbol': 'ETHTUSD', 'price': '1335.63000000'},
#  {'symbol': 'TUSDETH', 'price': '0.00762097'},
#  {'symbol': 'TUSDBNB', 'price': '0.06777000'},
#  {'symbol': 'ZENBTC', 'price': '0.00072300'},
#  {'symbol': 'ZENETH', 'price': '0.01019000'},
#  {'symbol': 'ZENBNB', 'price': '0.05130000'},
#  {'symbol': 'SKYBTC', 'price': '0.00000829'},
#  {'symbol': 'SKYETH', 'price': '0.00222000'},
#  {'symbol': 'SKYBNB', 'price': '0.03022000'},
#  {'symbol': 'EOSUSDT', 'price': '1.26200000'},
#  {'symbol': 'EOSBNB', 'price': '0.00470000'},
#  {'symbol': 'CVCBTC', 'price': '0.00000687'},
#  {'symbol': 'CVCETH', 'price': '0.00009930'},
#  {'symbol': 'CVCBNB', 'price': '0.00211200'},
#  {'symbol': 'THETABTC', 'price': '0.00005580'},
#  {'symbol': 'THETAETH', 'price': '0.00079500'},
#  {'symbol': 'THETABNB', 'price': '0.00397000'},
#  {'symbol': 'XRPBNB', 'price': '0.00153000'},
#  {'symbol': 'TUSDUSDT', 'price': '1.00000000'},
#  {'symbol': 'IOTAUSDT', 'price': '0.25840000'},
#  {'symbol': 'XLMUSDT', 'price': '0.11480000'},
#  {'symbol': 'IOTXBTC', 'price': '0.00000151'},
#  {'symbol': 'IOTXETH', 'price': '0.00002164'},
#  {'symbol': 'QKCBTC', 'price': '0.00000068'},
#  {'symbol': 'QKCETH', 'price': '0.00000952'},
#  {'symbol': 'AGIBTC', 'price': '0.00000668'},
#  {'symbol': 'AGIETH', 'price': '0.00007363'},
#  {'symbol': 'AGIBNB', 'price': '0.00077200'},
#  {'symbol': 'NXSBTC', 'price': '0.00000284'},
#  {'symbol': 'NXSETH', 'price': '0.00077300'},
#  {'symbol': 'NXSBNB', 'price': '0.01087000'},
#  {'symbol': 'ENJBNB', 'price': '0.00175200'},
#  {'symbol': 'DATABTC', 'price': '0.00000158'},
#  {'symbol': 'DATAETH', 'price': '0.00002034'},
#  {'symbol': 'ONTUSDT', 'price': '0.22180000'},
#  {'symbol': 'TRXBNB', 'price': '0.00022480'},
#  {'symbol': 'TRXUSDT', 'price': '0.06018000'},
#  {'symbol': 'ETCUSDT', 'price': '29.17000000'},
#  {'symbol': 'ETCBNB', 'price': '0.10890000'},
#  {'symbol': 'ICXUSDT', 'price': '0.24100000'},
#  {'symbol': 'SCBTC', 'price': '0.00000017'},
#  {'symbol': 'SCETH', 'price': '0.00000262'},
#  {'symbol': 'NPXSBTC', 'price': '0.00000003'},
#  {'symbol': 'NPXSETH', 'price': '0.00000345'},
#  {'symbol': 'VENUSDT', 'price': '0.00010000'},
#  {'symbol': 'KEYBTC', 'price': '0.00000013'},
#  {'symbol': 'KEYETH', 'price': '0.00000330'},
#  {'symbol': 'NASBTC', 'price': '0.00000228'},
#  {'symbol': 'NASETH', 'price': '0.00004047'},
#  {'symbol': 'NASBNB', 'price': '0.02337000'},
#  {'symbol': 'MFTBTC', 'price': '0.00000008'},
#  {'symbol': 'MFTETH', 'price': '0.00000368'},
#  {'symbol': 'MFTBNB', 'price': '0.00001485'},
#  {'symbol': 'DENTBTC', 'price': '0.00000004'},
#  {'symbol': 'DENTETH', 'price': '0.00000070'},
#  {'symbol': 'ARDRBTC', 'price': '0.00000520'},
#  {'symbol': 'ARDRETH', 'price': '0.00018870'},
#  {'symbol': 'ARDRBNB', 'price': '0.00316800'},
#  {'symbol': 'NULSUSDT', 'price': '0.18750000'},
#  {'symbol': 'HOTBTC', 'price': '0.00000002'},
#  {'symbol': 'HOTETH', 'price': '0.00000151'},
#  {'symbol': 'VETBTC', 'price': '0.00000119'},
#  {'symbol': 'VETETH', 'price': '0.00001683'},
#  {'symbol': 'VETUSDT', 'price': '0.02247000'},
#  {'symbol': 'VETBNB', 'price': '0.00008390'},
#  {'symbol': 'DOCKBTC', 'price': '0.00000115'},
#  {'symbol': 'DOCKETH', 'price': '0.00003283'},
#  {'symbol': 'POLYBTC', 'price': '0.00001027'},
#  {'symbol': 'POLYBNB', 'price': '0.00145900'},
#  {'symbol': 'PHXBTC', 'price': '0.00000180'},
#  {'symbol': 'PHXETH', 'price': '0.00005617'},
#  {'symbol': 'PHXBNB', 'price': '0.00045600'},
#  {'symbol': 'HCBTC', 'price': '0.00002000'},
#  {'symbol': 'HCETH', 'price': '0.00513400'},
#  {'symbol': 'GOBTC', 'price': '0.00000043'},
#  {'symbol': 'GOBNB', 'price': '0.00069230'},
#  {'symbol': 'PAXBTC', 'price': '0.00025175'},
#  {'symbol': 'PAXBNB', 'price': '0.20121000'},
#  {'symbol': 'PAXUSDT', 'price': '0.99960000'},
#  {'symbol': 'PAXETH', 'price': '0.00888047'},
#  {'symbol': 'RVNBTC', 'price': '0.00000206'},
#  {'symbol': 'DCRBTC', 'price': '0.00127700'},
#  {'symbol': 'DCRBNB', 'price': '0.78100000'},
#  {'symbol': 'USDCBNB', 'price': '0.21755000'},
#  {'symbol': 'MITHBTC', 'price': '0.00000110'},
#  {'symbol': 'MITHBNB', 'price': '0.00007900'},
#  {'symbol': 'BCHABCBTC', 'price': '0.02933000'},
#  {'symbol': 'BCHSVBTC', 'price': '0.01117900'},
#  {'symbol': 'BCHABCUSDT', 'price': '220.08000000'},
#  {'symbol': 'BCHSVUSDT', 'price': '58.90000000'},
#  {'symbol': 'BNBPAX', 'price': '495.10000000'},
#  {'symbol': 'BTCPAX', 'price': '51529.15000000'},
#  {'symbol': 'ETHPAX', 'price': '3904.41000000'},
#  {'symbol': 'XRPPAX', 'price': '0.88960000'},
#  {'symbol': 'EOSPAX', 'price': '2.58450000'},
#  {'symbol': 'XLMPAX', 'price': '0.04221000'},
#  {'symbol': 'RENBTC', 'price': '0.00000565'},
#  {'symbol': 'RENBNB', 'price': '0.00458500'},
#  {'symbol': 'BNBTUSD', 'price': '267.80000000'},
#  {'symbol': 'XRPTUSD', 'price': '0.41550000'},
#  {'symbol': 'EOSTUSD', 'price': '4.11590000'},
#  {'symbol': 'XLMTUSD', 'price': '0.06833000'},
#  {'symbol': 'BNBUSDC', 'price': '267.90000000'},
#  {'symbol': 'BTCUSDC', 'price': '19035.74000000'},
#  {'symbol': 'ETHUSDC', 'price': '1337.00000000'},
#  {'symbol': 'XRPUSDC', 'price': '0.41000000'},
#  {'symbol': 'EOSUSDC', 'price': '1.26800000'},
#  {'symbol': 'XLMUSDC', 'price': '0.04970000'},
#  {'symbol': 'USDCUSDT', 'price': '0.99990000'},
#  {'symbol': 'ADATUSD', 'price': '0.44610000'},
#  {'symbol': 'TRXTUSD', 'price': '0.06022000'},
#  {'symbol': 'NEOTUSD', 'price': '11.81800000'},
#  {'symbol': 'TRXXRP', 'price': '0.14693000'},
#  {'symbol': 'XZCXRP', 'price': '20.79200000'},
#  {'symbol': 'PAXTUSD', 'price': '0.99950000'},
#  {'symbol': 'USDCTUSD', 'price': '1.00000000'},
#  {'symbol': 'USDCPAX', 'price': '1.00020000'},
#  {'symbol': 'LINKUSDT', 'price': '7.04400000'},
#  {'symbol': 'LINKTUSD', 'price': '28.87000000'},
#  {'symbol': 'LINKPAX', 'price': '3.98340000'},
#  {'symbol': 'LINKUSDC', 'price': '7.05100000'},
#  {'symbol': 'WAVESUSDT', 'price': '4.04100000'},
#  {'symbol': 'WAVESTUSD', 'price': '1.07200000'},
#  {'symbol': 'WAVESPAX', 'price': '0.80290000'},
#  {'symbol': 'WAVESUSDC', 'price': '1.20360000'},
#  {'symbol': 'BCHABCTUSD', 'price': '220.20000000'},
#  {'symbol': 'BCHABCPAX', 'price': '221.20000000'},
#  {'symbol': 'BCHABCUSDC', 'price': '220.30000000'},
#  {'symbol': 'BCHSVTUSD', 'price': '59.17000000'},
#  {'symbol': 'BCHSVPAX', 'price': '58.18000000'},
#  {'symbol': 'BCHSVUSDC', 'price': '57.50000000'},
#  {'symbol': 'LTCTUSD', 'price': '150.10000000'},
#  {'symbol': 'LTCPAX', 'price': '171.13000000'},
#  {'symbol': 'LTCUSDC', 'price': '53.59000000'},
#  {'symbol': 'TRXPAX', 'price': '0.07661000'},
#  {'symbol': 'TRXUSDC', 'price': '0.06022000'},
#  {'symbol': 'BTTBTC', 'price': '0.00000005'},
#  {'symbol': 'BTTBNB', 'price': '0.00000573'},
#  {'symbol': 'BTTUSDT', 'price': '0.00277700'},
#  {'symbol': 'BNBUSDS', 'price': '22.27880000'},
#  {'symbol': 'BTCUSDS', 'price': '9604.59000000'},
#  {'symbol': 'USDSUSDT', 'price': '0.99680000'},
#  {'symbol': 'USDSPAX', 'price': '1.00020000'},
#  {'symbol': 'USDSTUSD', 'price': '1.00000000'},
#  {'symbol': 'USDSUSDC', 'price': '1.00000000'},
#  {'symbol': 'BTTPAX', 'price': '0.00038660'},
#  {'symbol': 'BTTTUSD', 'price': '0.00277000'},
#  {'symbol': 'BTTUSDC', 'price': '0.00277600'},
#  {'symbol': 'ONGBNB', 'price': '0.00545000'},
#  {'symbol': 'ONGBTC', 'price': '0.00001734'},
#  {'symbol': 'ONGUSDT', 'price': '0.33020000'},
#  {'symbol': 'HOTBNB', 'price': '0.00000862'},
#  {'symbol': 'HOTUSDT', 'price': '0.00202500'},
#  {'symbol': 'ZILUSDT', 'price': '0.03208000'},
#  {'symbol': 'ZRXBNB', 'price': '0.01045000'},
#  {'symbol': 'ZRXUSDT', 'price': '0.27020000'},
#  {'symbol': 'FETBNB', 'price': '0.00030300'},
#  {'symbol': 'FETBTC', 'price': '0.00000427'},
#  {'symbol': 'FETUSDT', 'price': '0.08130000'},
#  {'symbol': 'BATUSDT', 'price': '0.30120000'},
#  {'symbol': 'XMRBNB', 'price': '0.52690000'},
#  {'symbol': 'XMRUSDT', 'price': '141.60000000'},
#  {'symbol': 'ZECBNB', 'price': '0.20380000'},
#  {'symbol': 'ZECUSDT', 'price': '54.70000000'},
#  {'symbol': 'ZECPAX', 'price': '42.10000000'},
#  {'symbol': 'ZECTUSD', 'price': '51.48000000'},
#  {'symbol': 'ZECUSDC', 'price': '54.10000000'},
#  {'symbol': 'IOSTUSDT', 'price': '0.01210000'},
#  {'symbol': 'CELRBNB', 'price': '0.00005525'},
#  {'symbol': 'CELRBTC', 'price': '0.00000079'},
#  {'symbol': 'CELRUSDT', 'price': '0.01494000'},
#  {'symbol': 'ADAPAX', 'price': '0.03257000'},
#  {'symbol': 'ADAUSDC', 'price': '0.44780000'},
#  {'symbol': 'NEOPAX', 'price': '11.12200000'},
#  {'symbol': 'NEOUSDC', 'price': '28.27000000'},
#  {'symbol': 'DASHBNB', 'price': '0.15370000'},
#  {'symbol': 'DASHUSDT', 'price': '41.17000000'},
#  {'symbol': 'NANOUSDT', 'price': '2.22400000'},
#  {'symbol': 'OMGBNB', 'price': '0.03938000'},
#  {'symbol': 'OMGUSDT', 'price': '1.71100000'},
#  {'symbol': 'THETAUSDT', 'price': '1.06300000'},
#  {'symbol': 'ENJUSDT', 'price': '0.47400000'},
#  {'symbol': 'MITHUSDT', 'price': '0.02107000'},
#  {'symbol': 'MATICBNB', 'price': '0.00275000'},
#  {'symbol': 'MATICBTC', 'price': '0.00003867'},
#  {'symbol': 'MATICUSDT', 'price': '0.73570000'},
#  {'symbol': 'ATOMBNB', 'price': '0.05336000'},
#  {'symbol': 'ATOMBTC', 'price': '0.00074900'},
#  {'symbol': 'ATOMUSDT', 'price': '14.25400000'},
#  {'symbol': 'ATOMUSDC', 'price': '14.28400000'},
#  {'symbol': 'ATOMPAX', 'price': '3.17800000'},
#  {'symbol': 'ATOMTUSD', 'price': '2.59800000'},
#  {'symbol': 'ETCUSDC', 'price': '4.71000000'},
#  {'symbol': 'ETCPAX', 'price': '4.83800000'},
#  {'symbol': 'ETCTUSD', 'price': '3.79500000'},
#  {'symbol': 'BATUSDC', 'price': '0.63130000'},
#  {'symbol': 'BATPAX', 'price': '0.25560000'},
#  {'symbol': 'BATTUSD', 'price': '0.22220000'},
#  {'symbol': 'PHBBNB', 'price': '0.00013700'},
#  {'symbol': 'PHBBTC', 'price': '0.00003982'},
#  {'symbol': 'PHBUSDC', 'price': '0.00587000'},
#  {'symbol': 'PHBTUSD', 'price': '0.22900000'},
#  {'symbol': 'PHBPAX', 'price': '0.00639000'},
#  {'symbol': 'TFUELBNB', 'price': '0.00012590'},
#  {'symbol': 'TFUELBTC', 'price': '0.00000270'},
#  {'symbol': 'TFUELUSDT', 'price': '0.05150000'},
#  {'symbol': 'TFUELUSDC', 'price': '0.00356500'},
#  {'symbol': 'TFUELTUSD', 'price': '0.00307700'},
#  {'symbol': 'TFUELPAX', 'price': '0.00348700'},
#  {'symbol': 'ONEBNB', 'price': '0.00007050'},
#  {'symbol': 'ONEBTC', 'price': '0.00000099'},
#  {'symbol': 'ONEUSDT', 'price': '0.01896000'},
#  {'symbol': 'ONETUSD', 'price': '0.00472000'},
#  {'symbol': 'ONEPAX', 'price': '0.00496000'},
#  {'symbol': 'ONEUSDC', 'price': '0.00520000'},
#  {'symbol': 'FTMBNB', 'price': '0.00085640'},
#  {'symbol': 'FTMBTC', 'price': '0.00001205'},
#  {'symbol': 'FTMUSDT', 'price': '0.22940000'},
#  {'symbol': 'FTMTUSD', 'price': '0.01095000'},
#  {'symbol': 'FTMPAX', 'price': '0.01028000'},
#  {'symbol': 'FTMUSDC', 'price': '0.01107000'},
#  {'symbol': 'BTCBBTC', 'price': '1.00000000'},
#  {'symbol': 'BCPTTUSD', 'price': '0.02606000'},
#  {'symbol': 'BCPTPAX', 'price': '0.02761000'},
#  {'symbol': 'BCPTUSDC', 'price': '0.02728000'},
#  {'symbol': 'ALGOBNB', 'price': '0.00119100'},
#  {'symbol': 'ALGOBTC', 'price': '0.00001674'},
#  {'symbol': 'ALGOUSDT', 'price': '0.31850000'},
#  {'symbol': 'ALGOTUSD', 'price': '1.01700000'},
#  {'symbol': 'ALGOPAX', 'price': '0.20390000'},
#  {'symbol': 'ALGOUSDC', 'price': '0.23800000'},
#  {'symbol': 'USDSBUSDT', 'price': '0.99970000'},
#  {'symbol': 'USDSBUSDS', 'price': '0.99990000'},
#  {'symbol': 'GTOUSDT', 'price': '0.01974000'},
#  {'symbol': 'GTOPAX', 'price': '0.01361000'},
#  {'symbol': 'GTOTUSD', 'price': '0.01236000'},
#  {'symbol': 'GTOUSDC', 'price': '0.01196000'},
#  {'symbol': 'ERDBNB', 'price': '0.00083273'},
#  {'symbol': 'ERDBTC', 'price': '0.00000168'},
#  {'symbol': 'ERDUSDT', 'price': '0.01971000'},
#  {'symbol': 'ERDPAX', 'price': '0.00125270'},
#  {'symbol': 'ERDUSDC', 'price': '0.00135730'},
#  {'symbol': 'DOGEBNB', 'price': '0.00015270'},
#  {'symbol': 'DOGEBTC', 'price': '0.00000309'},
#  {'symbol': 'DOGEUSDT', 'price': '0.05884000'},
#  {'symbol': 'DOGEPAX', 'price': '0.00216820'},
#  {'symbol': 'DOGEUSDC', 'price': '0.00212770'},
#  {'symbol': 'DUSKBNB', 'price': '0.00118000'},
#  {'symbol': 'DUSKBTC', 'price': '0.00000592'},
#  {'symbol': 'DUSKUSDT', 'price': '0.11270000'},
#  {'symbol': 'DUSKUSDC', 'price': '0.01790000'},
#  {'symbol': 'DUSKPAX', 'price': '0.01890000'},
#  {'symbol': 'BGBPUSDC', 'price': '1.39000000'},
#  {'symbol': 'ANKRBNB', 'price': '0.00011350'},
#  {'symbol': 'ANKRBTC', 'price': '0.00000160'},
#  {'symbol': 'ANKRUSDT', 'price': '0.03043000'},
#  {'symbol': 'ANKRTUSD', 'price': '0.00212800'},
#  {'symbol': 'ANKRPAX', 'price': '0.00209300'},
#  {'symbol': 'ANKRUSDC', 'price': '0.00209700'},
#  {'symbol': 'ONTPAX', 'price': '0.84510000'},
#  {'symbol': 'ONTUSDC', 'price': '0.57080000'},
#  {'symbol': 'WINBNB', 'price': '0.00000037'},
#  {'symbol': 'WINBTC', 'price': '0.00000001'},
#  {'symbol': 'WINUSDT', 'price': '0.00009990'},
#  {'symbol': 'WINUSDC', 'price': '0.00009980'},
#  {'symbol': 'COSBNB', 'price': '0.00002266'},
#  {'symbol': 'COSBTC', 'price': '0.00000032'},
#  {'symbol': 'COSUSDT', 'price': '0.00606000'},
#  {'symbol': 'TUSDBTUSD', 'price': '0.99750000'},
#  {'symbol': 'NPXSUSDT', 'price': '0.00703010'},
#  {'symbol': 'NPXSUSDC', 'price': '0.00017020'},
#  {'symbol': 'COCOSBNB', 'price': '0.00222600'},
#  {'symbol': 'COCOSBTC', 'price': '0.00000003'},
#  {'symbol': 'COCOSUSDT', 'price': '0.59870000'},
#  {'symbol': 'MTLUSDT', 'price': '1.07500000'},
#  {'symbol': 'TOMOBNB', 'price': '0.03255000'},
#  {'symbol': 'TOMOBTC', 'price': '0.00002268'},
#  {'symbol': 'TOMOUSDT', 'price': '0.43140000'},
#  {'symbol': 'TOMOUSDC', 'price': '0.36700000'},
#  {'symbol': 'PERLBNB', 'price': '0.00007180'},
#  {'symbol': 'PERLBTC', 'price': '0.00000111'},
#  {'symbol': 'PERLUSDC', 'price': '0.02447000'},
#  {'symbol': 'PERLUSDT', 'price': '0.02125000'},
#  {'symbol': 'DENTUSDT', 'price': '0.00092800'},
#  {'symbol': 'MFTUSDT', 'price': '0.00496300'},
#  {'symbol': 'KEYUSDT', 'price': '0.00441300'},
#  {'symbol': 'STORMUSDT', 'price': '0.00339700'},
#  {'symbol': 'DOCKUSDT', 'price': '0.02199000'},
#  {'symbol': 'WANUSDT', 'price': '0.18320000'},
#  {'symbol': 'FUNUSDT', 'price': '0.00733000'},
#  {'symbol': 'CVCUSDT', 'price': '0.13060000'},
#  {'symbol': 'BTTTRX', 'price': '0.03945000'},
#  {'symbol': 'WINTRX', 'price': '0.00165400'},
#  {'symbol': 'CHZBNB', 'price': '0.00089000'},
#  {'symbol': 'CHZBTC', 'price': '0.00001252'},
#  {'symbol': 'CHZUSDT', 'price': '0.23840000'},
#  {'symbol': 'BANDBNB', 'price': '0.02248000'},
#  {'symbol': 'BANDBTC', 'price': '0.00006010'},
#  {'symbol': 'BANDUSDT', 'price': '1.14300000'},
#  {'symbol': 'BNBBUSD', 'price': '267.60000000'},
#  {'symbol': 'BTCBUSD', 'price': '19035.05000000'},
#  {'symbol': 'BUSDUSDT', 'price': '0.99990000'},
#  {'symbol': 'BEAMBNB', 'price': '0.02177000'},
#  {'symbol': 'BEAMBTC', 'price': '0.00000960'},
#  {'symbol': 'BEAMUSDT', 'price': '0.18290000'},
#  {'symbol': 'XTZBNB', 'price': '0.00547200'},
#  {'symbol': 'XTZBTC', 'price': '0.00007698'},
#  {'symbol': 'XTZUSDT', 'price': '1.46400000'},
#  {'symbol': 'RENUSDT', 'price': '0.10760000'},
#  {'symbol': 'RVNUSDT', 'price': '0.03906000'},
#  {'symbol': 'HCUSDT', 'price': '0.84230000'},
#  {'symbol': 'HBARBNB', 'price': '0.00021690'},
#  {'symbol': 'HBARBTC', 'price': '0.00000307'},
#  {'symbol': 'HBARUSDT', 'price': '0.05830000'},
#  {'symbol': 'NKNBNB', 'price': '0.00074700'},
#  {'symbol': 'NKNBTC', 'price': '0.00000484'},
#  {'symbol': 'NKNUSDT', 'price': '0.09190000'},
#  {'symbol': 'XRPBUSD', 'price': '0.40980000'},
#  {'symbol': 'ETHBUSD', 'price': '1337.31000000'},
#  {'symbol': 'BCHABCBUSD', 'price': '220.16000000'},
#  {'symbol': 'LTCBUSD', 'price': '53.57000000'},
#  {'symbol': 'LINKBUSD', 'price': '7.04300000'},
#  {'symbol': 'ETCBUSD', 'price': '29.17000000'},
#  {'symbol': 'STXBNB', 'price': '0.00122400'},
#  {'symbol': 'STXBTC', 'price': '0.00001730'},
#  {'symbol': 'STXUSDT', 'price': '0.32900000'},
#  {'symbol': 'KAVABNB', 'price': '0.00549000'},
#  {'symbol': 'KAVABTC', 'price': '0.00007760'},
#  {'symbol': 'KAVAUSDT', 'price': '1.47400000'},
#  {'symbol': 'BUSDNGN', 'price': '462.64000000'},
#  {'symbol': 'BNBNGN', 'price': '43608.00000000'},
#  {'symbol': 'BTCNGN', 'price': '25941597.00000000'},
#  {'symbol': 'ARPABNB', 'price': '0.00012530'},
#  {'symbol': 'ARPABTC', 'price': '0.00000176'},
#  {'symbol': 'ARPAUSDT', 'price': '0.03340000'},
#  {'symbol': 'TRXBUSD', 'price': '0.06020000'},
#  {'symbol': 'EOSBUSD', 'price': '1.26300000'},
#  {'symbol': 'IOTXUSDT', 'price': '0.02884000'},
#  {'symbol': 'RLCUSDT', 'price': '1.24200000'},
#  {'symbol': 'MCOUSDT', 'price': '2.74400000'},
#  {'symbol': 'XLMBUSD', 'price': '0.11480000'},
#  {'symbol': 'ADABUSD', 'price': '0.44800000'},
#  {'symbol': 'CTXCBNB', 'price': '0.00412200'},
#  {'symbol': 'CTXCBTC', 'price': '0.00000594'},
#  {'symbol': 'CTXCUSDT', 'price': '0.11300000'},
#  {'symbol': 'BCHBNB', 'price': '0.42900000'},
#  {'symbol': 'BCHBTC', 'price': '0.00604000'},
#  {'symbol': 'BCHUSDT', 'price': '114.90000000'},
#  {'symbol': 'BCHUSDC', 'price': '114.90000000'},
#  {'symbol': 'BCHTUSD', 'price': '630.00000000'},
#  {'symbol': 'BCHPAX', 'price': '617.72000000'},
#  {'symbol': 'BCHBUSD', 'price': '115.00000000'},
#  {'symbol': 'BTCRUB', 'price': '1164100.00000000'},
#  {'symbol': 'ETHRUB', 'price': '81724.70000000'},
#  {'symbol': 'XRPRUB', 'price': '25.02000000'},
#  {'symbol': 'BNBRUB', 'price': '16335.69000000'},
#  {'symbol': 'TROYBNB', 'price': '0.00001352'},
#  {'symbol': 'TROYBTC', 'price': '0.00000018'},
#  {'symbol': 'TROYUSDT', 'price': '0.00363100'},
#  {'symbol': 'BUSDRUB', 'price': '61.15000000'},
#  {'symbol': 'QTUMBUSD', 'price': '2.88000000'},
#  {'symbol': 'VETBUSD', 'price': '0.02248000'},
#  {'symbol': 'VITEBNB', 'price': '0.00070700'},
#  {'symbol': 'VITEBTC', 'price': '0.00000134'},
#  {'symbol': 'VITEUSDT', 'price': '0.02566000'},
#  {'symbol': 'FTTBNB', 'price': '0.08770000'},
#  {'symbol': 'FTTBTC', 'price': '0.00123680'},
#  {'symbol': 'FTTUSDT', 'price': '23.54000000'},
#  {'symbol': 'BTCTRY', 'price': '353978.00000000'},
#  {'symbol': 'BNBTRY', 'price': '4979.00000000'},
#  {'symbol': 'BUSDTRY', 'price': '18.59400000'},
#  {'symbol': 'ETHTRY', 'price': '24864.00000000'},
#  {'symbol': 'XRPTRY', 'price': '7.62100000'},
#  {'symbol': 'USDTTRY', 'price': '18.59800000'},
#  {'symbol': 'USDTRUB', 'price': '61.18000000'},
#  {'symbol': 'BTCEUR', 'price': '19329.08000000'},
#  {'symbol': 'ETHEUR', 'price': '1357.55000000'},
#  {'symbol': 'BNBEUR', 'price': '271.80000000'},
#  {'symbol': 'XRPEUR', 'price': '0.41620000'},
#  {'symbol': 'EURBUSD', 'price': '0.98490000'},
#  {'symbol': 'EURUSDT', 'price': '0.98470000'},
#  {'symbol': 'OGNBNB', 'price': '0.00054000'},
#  {'symbol': 'OGNBTC', 'price': '0.00000767'},
#  {'symbol': 'OGNUSDT', 'price': '0.14610000'},
#  {'symbol': 'DREPBNB', 'price': '0.00009380'},
#  {'symbol': 'DREPBTC', 'price': '0.00002746'},
#  {'symbol': 'DREPUSDT', 'price': '0.52340000'},
#  {'symbol': 'BULLUSDT', 'price': '1370.28000000'},
#  {'symbol': 'BULLBUSD', 'price': '1368.56000000'},
#  {'symbol': 'BEARUSDT', 'price': '11.16000000'},
#  {'symbol': 'BEARBUSD', 'price': '11.14000000'},
#  {'symbol': 'ETHBULLUSDT', 'price': '79.18000000'},
#  {'symbol': 'ETHBULLBUSD', 'price': '78.46000000'},
#  {'symbol': 'ETHBEARUSDT', 'price': '12.20000000'},
#  {'symbol': 'ETHBEARBUSD', 'price': '12.24000000'},
#  {'symbol': 'TCTBNB', 'price': '0.00041860'},
#  {'symbol': 'TCTBTC', 'price': '0.00000039'},
#  {'symbol': 'TCTUSDT', 'price': '0.00735000'},
#  {'symbol': 'WRXBNB', 'price': '0.00078200'},
#  {'symbol': 'WRXBTC', 'price': '0.00001098'},
#  {'symbol': 'WRXUSDT', 'price': '0.20910000'},
#  {'symbol': 'ICXBUSD', 'price': '0.24110000'},
#  {'symbol': 'BTSUSDT', 'price': '0.01417000'},
#  {'symbol': 'BTSBUSD', 'price': '0.01930000'},
#  {'symbol': 'LSKUSDT', 'price': '0.93000000'},
#  {'symbol': 'BNTUSDT', 'price': '0.43400000'},
#  {'symbol': 'BNTBUSD', 'price': '0.43100000'},
#  {'symbol': 'LTOBNB', 'price': '0.00248000'},
#  {'symbol': 'LTOBTC', 'price': '0.00000404'},
#  {'symbol': 'LTOUSDT', 'price': '0.07700000'},
#  {'symbol': 'ATOMBUSD', 'price': '14.26200000'},
#  {'symbol': 'DASHBUSD', 'price': '41.25000000'},
#  {'symbol': 'NEOBUSD', 'price': '8.37000000'},
#  {'symbol': 'WAVESBUSD', 'price': '4.04300000'},
#  {'symbol': 'XTZBUSD', 'price': '1.46500000'},
#  {'symbol': 'EOSBULLUSDT', 'price': '3.85000000'},
#  {'symbol': 'EOSBULLBUSD', 'price': '3.90000000'},
#  {'symbol': 'EOSBEARUSDT', 'price': '30.21000000'},
#  {'symbol': 'EOSBEARBUSD', 'price': '29.81000000'},
#  {'symbol': 'XRPBULLUSDT', 'price': '8.74000000'},
#  {'symbol': 'XRPBULLBUSD', 'price': '8.78000000'},
#  {'symbol': 'XRPBEARUSDT', 'price': '548.55000000'},
#  {'symbol': 'XRPBEARBUSD', 'price': '547.33000000'},
#  {'symbol': 'BATBUSD', 'price': '0.30100000'},
#  {'symbol': 'ENJBUSD', 'price': '0.47410000'},
#  {'symbol': 'NANOBUSD', 'price': '2.22500000'},
#  {'symbol': 'ONTBUSD', 'price': '0.22220000'},
#  {'symbol': 'RVNBUSD', 'price': '0.03912000'},
#  {'symbol': 'STRATBUSD', 'price': '0.49150000'},
#  {'symbol': 'STRATBNB', 'price': '0.01900000'},
#  {'symbol': 'STRATUSDT', 'price': '0.49040000'},
#  {'symbol': 'AIONBUSD', 'price': '0.07210000'},
#  {'symbol': 'AIONUSDT', 'price': '0.04044000'},
#  {'symbol': 'MBLBNB', 'price': '0.00001202'},
#  {'symbol': 'MBLBTC', 'price': '0.00000005'},
#  {'symbol': 'MBLUSDT', 'price': '0.00345700'},
#  {'symbol': 'COTIBNB', 'price': '0.00034590'},
#  {'symbol': 'COTIBTC', 'price': '0.00000491'},
#  {'symbol': 'COTIUSDT', 'price': '0.09340000'},
#  {'symbol': 'ALGOBUSD', 'price': '0.31850000'},
#  {'symbol': 'BTTBUSD', 'price': '0.00277800'},
#  {'symbol': 'TOMOBUSD', 'price': '0.43000000'},
#  {'symbol': 'XMRBUSD', 'price': '141.50000000'},
#  {'symbol': 'ZECBUSD', 'price': '54.70000000'},
#  {'symbol': 'BNBBULLUSDT', 'price': '57.21000000'},
#  {'symbol': 'BNBBULLBUSD', 'price': '58.37000000'},
#  {'symbol': 'BNBBEARUSDT', 'price': '58.61000000'},
#  {'symbol': 'BNBBEARBUSD', 'price': '57.21000000'},
#  {'symbol': 'STPTBNB', 'price': '0.00067000'},
#  {'symbol': 'STPTBTC', 'price': '0.00000227'},
#  {'symbol': 'STPTUSDT', 'price': '0.04315000'},
#  {'symbol': 'BTCZAR', 'price': '857014.00000000'},
#  {'symbol': 'ETHZAR', 'price': '27850.40000000'},
#  {'symbol': 'BNBZAR', 'price': '5000.00000000'},
#  {'symbol': 'USDTZAR', 'price': '14.02300000'},
#  {'symbol': 'BUSDZAR', 'price': '13.88800000'},
#  {'symbol': 'BTCBKRW', 'price': '42029197.00000000'},
#  {'symbol': 'ETHBKRW', 'price': '1277799.00000000'},
#  {'symbol': 'BNBBKRW', 'price': '44687.00000000'},
#  {'symbol': 'WTCUSDT', 'price': '0.27050000'},
#  {'symbol': 'DATABUSD', 'price': '0.03010000'},
#  {'symbol': 'DATAUSDT', 'price': '0.03025000'},
#  {'symbol': 'XZCUSDT', 'price': '4.44600000'},
#  {'symbol': 'SOLBNB', 'price': '0.11870000'},
#  {'symbol': 'SOLBTC', 'price': '0.00166920'},
#  {'symbol': 'SOLUSDT', 'price': '31.80000000'},
#  {'symbol': 'SOLBUSD', 'price': '31.78000000'},
#  {'symbol': 'BTCIDRT', 'price': '693891182.00'},
#  {'symbol': 'BNBIDRT', 'price': '4286985.00'},
#  {'symbol': 'USDTIDRT', 'price': '15004.00'},
#  {'symbol': 'BUSDIDRT', 'price': '14389.00'},
#  {'symbol': 'CTSIBTC', 'price': '0.00000703'},
#  {'symbol': 'CTSIUSDT', 'price': '0.13390000'},
#  {'symbol': 'CTSIBNB', 'price': '0.00049900'},
#  {'symbol': 'CTSIBUSD', 'price': '0.13380000'},
#  {'symbol': 'HIVEBNB', 'price': '0.00429000'},
#  {'symbol': 'HIVEBTC', 'price': '0.00002625'},
#  {'symbol': 'HIVEUSDT', 'price': '0.49970000'},
#  {'symbol': 'CHRBNB', 'price': '0.00054040'},
#  {'symbol': 'CHRBTC', 'price': '0.00000760'},
#  {'symbol': 'CHRUSDT', 'price': '0.14460000'},
#  {'symbol': 'BTCUPUSDT', 'price': '3.83900000'},
#  {'symbol': 'BTCDOWNUSDT', 'price': '0.03631400'},
#  {'symbol': 'GXSUSDT', 'price': '1.79230000'},
#  {'symbol': 'ARDRUSDT', 'price': '0.09880000'},
#  {'symbol': 'ERDBUSD', 'price': '0.01966100'},
#  {'symbol': 'LENDUSDT', 'price': '0.51431000'},
#  {'symbol': 'HBARBUSD', 'price': '0.05830000'},
#  {'symbol': 'MATICBUSD', 'price': '0.73610000'},
#  {'symbol': 'WRXBUSD', 'price': '0.20910000'},
#  {'symbol': 'ZILBUSD', 'price': '0.03211000'},
#  {'symbol': 'MDTBNB', 'price': '0.00073720'},
#  {'symbol': 'MDTBTC', 'price': '0.00000130'},
#  {'symbol': 'MDTUSDT', 'price': '0.02479000'},
#  {'symbol': 'STMXBTC', 'price': '0.00000037'},
#  {'symbol': 'STMXETH', 'price': '0.00000533'},
#  {'symbol': 'STMXUSDT', 'price': '0.00714300'},
#  {'symbol': 'KNCBUSD', 'price': '1.26200000'},
#  {'symbol': 'KNCUSDT', 'price': '1.26100000'},
#  {'symbol': 'REPBUSD', 'price': '13.67300000'},
#  {'symbol': 'REPUSDT', 'price': '7.03000000'},
#  {'symbol': 'LRCBUSD', 'price': '0.30180000'},
#  {'symbol': 'LRCUSDT', 'price': '0.30170000'},
#  {'symbol': 'IQBNB', 'price': '0.00002243'},
#  {'symbol': 'IQBUSD', 'price': '0.00490000'},
#  {'symbol': 'PNTBTC', 'price': '0.00001321'},
#  {'symbol': 'PNTUSDT', 'price': '0.25230000'},
#  {'symbol': 'BTCGBP', 'price': '16868.37000000'},
#  {'symbol': 'ETHGBP', 'price': '1185.05000000'},
#  {'symbol': 'XRPGBP', 'price': '0.36370000'},
#  {'symbol': 'BNBGBP', 'price': '237.40000000'},
#  {'symbol': 'GBPBUSD', 'price': '1.12800000'},
#  {'symbol': 'DGBBTC', 'price': '0.00000049'},
#  {'symbol': 'DGBBUSD', 'price': '0.00924000'},
#  {'symbol': 'BTCUAH', 'price': '777096.00000000'},
#  {'symbol': 'USDTUAH', 'price': '40.85000000'},
#  {'symbol': 'COMPBTC', 'price': '0.00295300'},
#  {'symbol': 'COMPBNB', 'price': '5.71900000'},
#  {'symbol': 'COMPBUSD', 'price': '56.17000000'},
#  {'symbol': 'COMPUSDT', 'price': '56.23000000'},
#  {'symbol': 'BTCBIDR', 'price': '286143321.00'},
#  {'symbol': 'ETHBIDR', 'price': '20069000.00'},
#  {'symbol': 'BNBBIDR', 'price': '4020019.00'},
#  {'symbol': 'BUSDBIDR', 'price': '15027.00'},
#  {'symbol': 'USDTBIDR', 'price': '15025.00'},
#  {'symbol': 'BKRWUSDT', 'price': '0.00084530'},
#  {'symbol': 'BKRWBUSD', 'price': '0.00084550'},
#  {'symbol': 'SCUSDT', 'price': '0.00350000'},
#  {'symbol': 'ZENUSDT', 'price': '13.75000000'},
#  {'symbol': 'SXPBTC', 'price': '0.00001766'},
#  {'symbol': 'SXPBNB', 'price': '0.00125600'},
#  {'symbol': 'SXPBUSD', 'price': '0.33620000'},
#  {'symbol': 'SNXBTC', 'price': '0.00012520'},
#  {'symbol': 'SNXBNB', 'price': '0.00887000'},
#  {'symbol': 'SNXBUSD', 'price': '2.38500000'},
#  {'symbol': 'SNXUSDT', 'price': '2.38200000'},
#  {'symbol': 'ETHUPUSDT', 'price': '3.28300000'},
#  {'symbol': 'ETHDOWNUSDT', 'price': '1.10500000'},
#  {'symbol': 'ADAUPUSDT', 'price': '0.98700000'},
#  {'symbol': 'ADADOWNUSDT', 'price': '0.00452600'},
#  {'symbol': 'LINKUPUSDT', 'price': '0.01137000'},
#  {'symbol': 'LINKDOWNUSDT', 'price': '0.00710500'},
#  {'symbol': 'VTHOBNB', 'price': '0.00000673'},
#  {'symbol': 'VTHOBUSD', 'price': '0.00071800'},
#  {'symbol': 'VTHOUSDT', 'price': '0.00141400'},
#  {'symbol': 'DCRBUSD', 'price': '16.03500000'},
#  {'symbol': 'DGBUSDT', 'price': '0.00924000'},
#  {'symbol': 'GBPUSDT', 'price': '1.13000000'},
#  {'symbol': 'STORJBUSD', 'price': '0.46430000'},
#  {'symbol': 'SXPUSDT', 'price': '0.33590000'},
#  {'symbol': 'IRISBNB', 'price': '0.00166200'},
#  {'symbol': 'IRISBTC', 'price': '0.00000097'},
#  {'symbol': 'IRISBUSD', 'price': '0.06080000'},
#  {'symbol': 'MKRBNB', 'price': '6.90300000'},
#  {'symbol': 'MKRBTC', 'price': '0.03266000'},
#  {'symbol': 'MKRUSDT', 'price': '621.00000000'},
#  {'symbol': 'MKRBUSD', 'price': '621.00000000'},
#  {'symbol': 'DAIBNB', 'price': '0.04876000'},
#  {'symbol': 'DAIBTC', 'price': '0.00008966'},
#  {'symbol': 'DAIUSDT', 'price': '1.01890000'},
#  {'symbol': 'DAIBUSD', 'price': '1.01810000'},
#  {'symbol': 'RUNEBNB', 'price': '0.00606000'},
#  {'symbol': 'RUNEBTC', 'price': '0.00008540'},
#  {'symbol': 'RUNEBUSD', 'price': '1.62500000'},
#  {'symbol': 'MANABUSD', 'price': '0.71130000'},
#  {'symbol': 'DOGEBUSD', 'price': '0.05887000'},
#  {'symbol': 'LENDBUSD', 'price': '0.51530000'},
#  {'symbol': 'ZRXBUSD', 'price': '0.27040000'},
#  {'symbol': 'DCRUSDT', 'price': '24.30000000'},
#  {'symbol': 'STORJUSDT', 'price': '0.46290000'},
#  {'symbol': 'XRPBKRW', 'price': '319.76000000'},
#  {'symbol': 'ADABKRW', 'price': '327.55000000'},
#  {'symbol': 'BTCAUD', 'price': '28670.07000000'},
#  {'symbol': 'ETHAUD', 'price': '2015.67000000'},
#  {'symbol': 'AUDBUSD', 'price': '0.66340000'},
#  {'symbol': 'FIOBNB', 'price': '0.00017080'},
#  {'symbol': 'FIOBTC', 'price': '0.00000222'},
#  {'symbol': 'FIOBUSD', 'price': '0.04240000'},
#  {'symbol': 'BNBUPUSDT', 'price': '29.44000000'},
#  {'symbol': 'BNBDOWNUSDT', 'price': '0.04531000'},
#  {'symbol': 'XTZUPUSDT', 'price': '0.00255100'},
#  {'symbol': 'XTZDOWNUSDT', 'price': '2.60010000'},
#  {'symbol': 'AVABNB', 'price': '0.00218800'},
#  {'symbol': 'AVABTC', 'price': '0.00003926'},
#  {'symbol': 'AVABUSD', 'price': '0.74600000'},
#  {'symbol': 'USDTBKRW', 'price': '1125.00000000'},
#  {'symbol': 'BUSDBKRW', 'price': '1097.18000000'},
#  {'symbol': 'IOTABUSD', 'price': '0.25890000'},
#  {'symbol': 'MANAUSDT', 'price': '0.71160000'},
#  {'symbol': 'XRPAUD', 'price': '0.61770000'},
#  {'symbol': 'BNBAUD', 'price': '403.60000000'},
#  {'symbol': 'AUDUSDT', 'price': '0.66360000'},
#  {'symbol': 'BALBNB', 'price': '0.42580000'},
#  {'symbol': 'BALBTC', 'price': '0.00028540'},
#  {'symbol': 'BALBUSD', 'price': '5.44400000'},
#  {'symbol': 'YFIBNB', 'price': '82.19000000'},
#  {'symbol': 'YFIBTC', 'price': '0.44210000'},
#  {'symbol': 'YFIBUSD', 'price': '8414.00000000'},
#  {'symbol': 'YFIUSDT', 'price': '8413.00000000'},
#  {'symbol': 'BLZBUSD', 'price': '0.08200000'},
#  {'symbol': 'KMDBUSD', 'price': '0.46760000'},
#  {'symbol': 'BALUSDT', 'price': '5.41500000'},
#  {'symbol': 'BLZUSDT', 'price': '0.08190000'},
#  {'symbol': 'IRISUSDT', 'price': '0.01851000'},
#  {'symbol': 'KMDUSDT', 'price': '0.25650000'},
#  {'symbol': 'BTCDAI', 'price': '19030.57000000'},
#  {'symbol': 'ETHDAI', 'price': '1337.51000000'},
#  {'symbol': 'BNBDAI', 'price': '267.60000000'},
#  {'symbol': 'USDTDAI', 'price': '1.00030000'},
#  {'symbol': 'BUSDDAI', 'price': '1.00020000'},
#  {'symbol': 'JSTBNB', 'price': '0.00021850'},
#  {'symbol': 'JSTBTC', 'price': '0.00000132'},
#  {'symbol': 'JSTBUSD', 'price': '0.02493000'},
#  {'symbol': 'JSTUSDT', 'price': '0.02521000'},
#  {'symbol': 'SRMBNB', 'price': '0.00285000'},
#  {'symbol': 'SRMBTC', 'price': '0.00004010'},
#  {'symbol': 'SRMBUSD', 'price': '0.76400000'},
#  {'symbol': 'SRMUSDT', 'price': '0.76300000'},
#  {'symbol': 'ANTBNB', 'price': '0.00607000'},
#  {'symbol': 'ANTBTC', 'price': '0.00008546'},
#  {'symbol': 'ANTBUSD', 'price': '1.62900000'},
#  {'symbol': 'ANTUSDT', 'price': '1.62800000'},
#  {'symbol': 'CRVBNB', 'price': '0.00687000'},
#  {'symbol': 'CRVBTC', 'price': '0.00004812'},
#  {'symbol': 'CRVBUSD', 'price': '0.91600000'},
#  {'symbol': 'CRVUSDT', 'price': '0.91600000'},
#  {'symbol': 'SANDBNB', 'price': '0.00318000'},
#  {'symbol': 'SANDBTC', 'price': '0.00004472'},
#  {'symbol': 'SANDUSDT', 'price': '0.85060000'},
#  {'symbol': 'SANDBUSD', 'price': '0.85050000'},
#  {'symbol': 'OCEANBNB', 'price': '0.00057000'},
#  {'symbol': 'OCEANBTC', 'price': '0.00000803'},
#  {'symbol': 'OCEANBUSD', 'price': '0.15270000'},
#  {'symbol': 'OCEANUSDT', 'price': '0.15270000'},
#  {'symbol': 'NMRBTC', 'price': '0.00079600'},
#  {'symbol': 'NMRBUSD', 'price': '15.16000000'},
#  {'symbol': 'NMRUSDT', 'price': '15.16000000'},
#  {'symbol': 'DOTBNB', 'price': '0.02347000'},
#  {'symbol': 'DOTBTC', 'price': '0.00033030'},
#  {'symbol': 'DOTBUSD', 'price': '6.29000000'},
#  {'symbol': 'DOTUSDT', 'price': '6.28000000'},
#  {'symbol': 'LUNABNB', 'price': '0.00000019'},
#  {'symbol': 'LUNABTC', 'price': '0.00000001'},
#  {'symbol': 'LUNABUSD', 'price': '2.54160000'},
#  {'symbol': 'LUNAUSDT', 'price': '2.54080000'},
#  {'symbol': 'IDEXBTC', 'price': '0.00000326'},
#  {'symbol': 'IDEXBUSD', 'price': '0.06202000'},
#  {'symbol': 'RSRBNB', 'price': '0.00002050'},
#  {'symbol': 'RSRBTC', 'price': '0.00000016'},
#  {'symbol': 'RSRBUSD', 'price': '0.00551000'},
#  {'symbol': 'RSRUSDT', 'price': '0.00551000'},
#  {'symbol': 'PAXGBNB', 'price': '6.18600000'},
#  {'symbol': 'PAXGBTC', 'price': '0.08715000'},
#  {'symbol': 'PAXGBUSD', 'price': '1659.00000000'},
#  {'symbol': 'PAXGUSDT', 'price': '1659.00000000'},
#  {'symbol': 'WNXMBNB', 'price': '0.17350000'},
#  {'symbol': 'WNXMBTC', 'price': '0.00067200'},
#  {'symbol': 'WNXMBUSD', 'price': '22.16500000'},
#  {'symbol': 'WNXMUSDT', 'price': '14.87000000'},
#  {'symbol': 'TRBBNB', 'price': '0.51700000'},
#  {'symbol': 'TRBBTC', 'price': '0.00073300'},
#  {'symbol': 'TRBBUSD', 'price': '13.95000000'},
#  {'symbol': 'TRBUSDT', 'price': '13.92000000'},
#  {'symbol': 'ETHNGN', 'price': '805670.00000000'},
#  {'symbol': 'DOTBIDR', 'price': '93999.00'},
#  {'symbol': 'LINKAUD', 'price': '10.62800000'},
#  {'symbol': 'SXPAUD', 'price': '1.86800000'},
#  {'symbol': 'BZRXBNB', 'price': '0.00514000'},
#  {'symbol': 'BZRXBTC', 'price': '0.00000463'},
#  {'symbol': 'BZRXBUSD', 'price': '0.21640000'},
#  {'symbol': 'BZRXUSDT', 'price': '0.21560000'},
#  {'symbol': 'WBTCBTC', 'price': '1.00030000'},
#  {'symbol': 'WBTCETH', 'price': '14.24000000'},
#  {'symbol': 'SUSHIBNB', 'price': '0.00393000'},
#  {'symbol': 'SUSHIBTC', 'price': '0.00005540'},
#  {'symbol': 'SUSHIBUSD', 'price': '1.05300000'},
#  {'symbol': 'SUSHIUSDT', 'price': '1.05300000'},
#  {'symbol': 'YFIIBNB', 'price': '4.42000000'},
#  {'symbol': 'YFIIBTC', 'price': '0.04630000'},
#  {'symbol': 'YFIIBUSD', 'price': '1192.00000000'},
#  {'symbol': 'YFIIUSDT', 'price': '882.70000000'},
#  {'symbol': 'KSMBNB', 'price': '0.15690000'},
#  {'symbol': 'KSMBTC', 'price': '0.00221400'},
#  {'symbol': 'KSMBUSD', 'price': '42.19000000'},
#  {'symbol': 'KSMUSDT', 'price': '42.11000000'},
#  {'symbol': 'EGLDBNB', 'price': '0.17680000'},
#  ...]

# %%
df = pd.DataFrame(prices)
df
# Out:
#         symbol       price
# 0       ETHBTC  0.07026300
# 1       LTCBTC  0.00281500
# 2       BNBBTC  0.01406700
# 3       NEOBTC  0.00044000
# 4      QTUMETH  0.00215200
# ...        ...         ...
# 2096   PHBBUSD  0.76000000
# 2097   GASBUSD  2.30600000
# 2098  NEBLBUSD  1.74100000
# 2099  PROSBUSD  0.78390000
# 2100   VIBBUSD  0.08483000
#
# [2101 rows x 2 columns]

# %%
df[df.symbol.str.contains("ETH")]
# Out:
#         symbol          price
# 0       ETHBTC     0.07026300
# 4      QTUMETH     0.00215200
# 5       EOSETH     0.00094400
# 6       SNTETH     0.00002151
# 7       BNTETH     0.00032500
# ...        ...            ...
# 2078   BONDETH     0.00379200
# 2080     OPETH     0.00068900
# 2082   WINGETH     0.00670700
# 2083    FILETH     0.00399900
# 2091  BETHBUSD  1314.23000000
#
# [245 rows x 2 columns]

# %%
df[df.symbol.str.contains("BTC") & df.symbol.str.contains("USD")]
# Out:
#            symbol           price
# 11        BTCUSDT  19033.65000000
# 312       BTCTUSD  19018.68000000
# 313       TUSDBTC      0.00025971
# 417       BTCUSDC  19035.74000000
# 454       BTCUSDS   9604.59000000
# 614       BTCBUSD  19035.05000000
# 795     BTCUPUSDT      3.83900000
# 796   BTCDOWNUSDT      0.03631400
# 1190      SUSDBTC      0.00002065
# 1240    BTCSTBUSD      8.99000000
# 1241    BTCSTUSDT      8.98000000
# 1621      BTCUSDP  18868.45000000
# 2070     WBTCBUSD  19046.41000000

# %%
df[df.symbol.str.contains("BTC") & df.symbol.str.contains("EUR")]
# Out:
#      symbol           price
# 689  BTCEUR  19329.08000000

# %%
last24 = client.get_ticker(symbol = "BTCUSDT") # 24H Price change statistic
last24
# Out:
# {'symbol': 'BTCUSDT',
#  'priceChange': '121.87000000',
#  'priceChangePercent': '0.645',
#  'weightedAvgPrice': '19079.73585847',
#  'prevClosePrice': '18897.10000000',
#  'lastPrice': '19019.04000000',
#  'lastQty': '0.01093000',
#  'bidPrice': '19017.41000000',
#  'bidQty': '0.02500000',
#  'askPrice': '19019.04000000',
#  'askQty': '0.00507000',
#  'openPrice': '18897.17000000',
#  'highPrice': '19956.00000000',
#  'lowPrice': '18666.00000000',
#  'volume': '311802.87970000',
#  'quoteVolume': '5949116584.58477670',
#  'openTime': 1663698617983,
#  'closeTime': 1663785017983,
#  'firstId': 1849387041,
#  'lastId': 1855107601,
#  'count': 5720561}

# %%
last24["openTime"]

# %%
pd.to_datetime(last24["openTime"], unit = "ms")

# %%
pd.to_datetime(last24["closeTime"], unit = "ms")

# %%
open_price = float(last24["openPrice"])
open_price

# %%
high_price = float(last24["highPrice"])
high_price

# %%
low_price = float(last24["lowPrice"])
low_price

# %%
close_price = float(last24["lastPrice"])
close_price

# %%
close_price - open_price

# %%
(close_price/open_price - 1) * 100

# %% [markdown]
# ## Getting Historical Data (OHLC & Volume) - Part 1

# %%
from binance.client import Client
import pandas as pd

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com")

# %%
timestamp = client._get_earliest_valid_timestamp(symbol = "BTCUSDT", interval = "1d")
timestamp # earliest data available on Binance

# %%
pd.to_datetime(timestamp, unit = "ms") # earliest data available on Binance

# %%
bars = client.get_historical_klines(symbol = "BTCUSDT",
                                    interval = "1d", start_str = timestamp, limit = 1000)
bars

# %%
df = pd.DataFrame(bars)
df

# %%
df["Date"] = pd.to_datetime(df.iloc[:,0], unit = "ms")

# %%
df

# %%
df.columns = ["Open Time", "Open", "High", "Low", "Close",
              "Volume", "Clos Time", "Quote Asset Volume", 
              "Number of Trades", "Taker Buy Base Asset Volume",
              "Taker Buy Quote Asset Volume", "Ignore", "Date" ]

# %%
df

# %%
df = df[["Date", "Open", "High", "Low", "Close", "Volume"]].copy()

# %%
df

# %%
df.set_index("Date", inplace = True)

# %%
df

# %%
df.info()

# %%
for column in df.columns:
    df[column] = pd.to_numeric(df[column], errors = "coerce")

# %% [markdown]
# ## Getting Historical Data (OHLC & Volume) - Part 2

# %%
def get_history(symbol, interval, start, end = None):
    bars = client.get_historical_klines(symbol = symbol, interval = interval,
                                        start_str = start, end_str = end, limit = 1000)
    df = pd.DataFrame(bars)
    df["Date"] = pd.to_datetime(df.iloc[:,0], unit = "ms")
    df.columns = ["Open Time", "Open", "High", "Low", "Close", "Volume",
                  "Clos Time", "Quote Asset Volume", "Number of Trades",
                  "Taker Buy Base Asset Volume", "Taker Buy Quote Asset Volume", "Ignore", "Date"]
    df = df[["Date", "Open", "High", "Low", "Close", "Volume"]].copy()
    df.set_index("Date", inplace = True)
    for column in df.columns:
        df[column] = pd.to_numeric(df[column], errors = "coerce")
    
    return df

# %%
timestamp

# %% [markdown]
# __Daily Data until Today/Now__

# %%
df = get_history(symbol = "BTCUSDT", interval = "1d", start = timestamp)
df

# %%
df.info()

# %% [markdown]
# __Daily Data for specified Time Period__

# %%
df = get_history(symbol = "BTCUSDT", interval = "1d", start = "2021-01-01", end = "2021-06-30")
df

# %% [markdown]
# valid intervals - 1m, 3m, 5m, 15m, 30m, 1h, 2h, 4h, 6h, 8h, 12h, 1d, 3d, 1w, 1M

# %% [markdown]
# __Weekly Data for specified Time Period__

# %%
df = get_history(symbol = "BTCUSDT", interval = "1w", start = "2021-01-01", end = "2021-06-30")
df

# %% [markdown]
# __Monthly Data for specified Time Period__

# %%
df = get_history(symbol = "BTCUSDT", interval = "1M", start = "2021-01-01", end = "2021-06-15")
df

# %% [markdown]
# __Most recent Monthly Data (until today/now)__

# %%
df = get_history(symbol = "BTCUSDT", interval = "1M", start = "2021-01-01")
df

# %% [markdown]
# __Intraday Data (1H) for specified Time Period__

# %%
df = get_history(symbol = "BTCUSDT", interval = "1h", start = "2021-10-01", end = "2021-10-05")
df

# %%
df = get_history(symbol = "BTCUSDT", interval = "1h",
                 start = "2021-10-01 10:00:00", end = "2021-10-05 16:00:00")
df

# %% [markdown]
# __Intraday Data (1m) for specified Time Period__

# %%
df = get_history(symbol = "BTCUSDT", interval = "1m",
                 start = "2021-10-01 10:29:00", end = "2021-10-05 16:55:00")
df

# %% [markdown]
# __Most recent (last 2 hours) Intraday Data (1m)__

# %%
from datetime import datetime, timedelta

# %%
now = datetime.utcnow()
now

# %%
two_hours_before = now - timedelta(hours = 2)
two_hours_before

# %%
str(two_hours_before)

# %%
df = get_history(symbol = "BTCUSDT", interval = "1m", start = str(two_hours_before))
df

# %% [markdown]
# ## Excursus: Loading Historical Data (csv) from the Website

# %%
import pandas as pd

# %%
url = r"C:\Users\hagma\OneDrive\Desktop\BTCUSDT-1h-2021-09\BTCUSDT-1h-2021-09.csv" # insert your filepath here
url

# %%
df = pd.read_csv(url, header = None)
df

# %%
df["Date"] = pd.to_datetime(df.iloc[:,0], unit = "ms")
df

# %%
df.columns = ["Open Time", "Open", "High", "Low", "Close", "Volume",
                  "Clos Time", "Quote Asset Volume", "Number of Trades",
                  "Taker Buy Base Asset Volume", "Taker Buy Quote Asset Volume", "Ignore", "Date"]
df

# %%
df = df[["Date", "Open", "High", "Low", "Close", "Volume"]].copy()
df.set_index("Date", inplace = True)

#not required:
#for column in df.columns:
    #df[column] = pd.to_numeric(df[column], errors = "coerce")

# %%
df

# %%
df.info()

# %% [markdown]
# ## Streaming Market Data (Part 1)

# %%
from binance import ThreadedWebsocketManager
import pandas as pd

# %%
def stream_data(msg):
    ''' define how to process incoming WebSocket messages '''
    print(msg)

# %%
# initialize and start the WebSocket
twm = ThreadedWebsocketManager()
twm.start()

# %% [markdown]
# If you have an account on __Binance.US__ (US residents) <br>
# (If you are using an exchange from the US, Japan or other TLD then make sure pass tld=’us’ when initializing the TWM.)

# %%
# initialize and start the WebSocket in the us
# twm = ThreadedWebsocketManager(tld = "us")
# twm.start()

# %%
twm

# %% [markdown]
# __Different Market Streams available:__ https://binance-docs.github.io/apidocs/spot/en/#websocket-market-streams

# %% [markdown]
# __Individual Symbol Mini Ticker:__ 24hr rolling window mini-ticker statistics. These are NOT the statistics of the UTC day, but a 24hr rolling window for the previous 24hrs.

# %%
# subscribe to the stream
twm.start_symbol_miniticker_socket(callback = stream_data, symbol = "BTCUSDT")

# %%
twm.stop() # stop the Websocket/Stream

# %% [markdown]
# __Individual Symbol Mini Ticker Output/Message:__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Streaming Market Data (Part 2)

# %%
def stream_data(msg):
    ''' define how to process incoming WebSocket messages '''
    
    time = pd.to_datetime(msg["E"], unit = "ms")
    price = msg["c"]
    
    print("Time: {} | Price: {}".format(time, price))

# %%
twm = ThreadedWebsocketManager()
twm.start()

# %%
twm.start_symbol_miniticker_socket(callback = stream_data, symbol = "BTCUSDT")

# %%
twm.stop()

# %% [markdown]
# ## Streaming and Collecting Real-Time Candles

# %%
from binance import ThreadedWebsocketManager
import pandas as pd

# %% [markdown]
# __Kline/Candlestick Stream:__ push updates to the current klines/candlestick every second.

# %% [markdown]
# https://binance-docs.github.io/apidocs/spot/en/#kline-candlestick-streams

# %% [markdown]
# __Output/Message:__

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.DataFrame(columns = ["Open", "High", "Low", "Close", "Volume", "Complete"])
df

# %%
def stream_candles(msg):
    ''' define how to process incoming WebSocket messages '''
    
    # extract the required items from msg
    event_time = pd.to_datetime(msg["E"], unit = "ms")
    start_time = pd.to_datetime(msg["k"]["t"], unit = "ms")
    first   = float(msg["k"]["o"])
    high    = float(msg["k"]["h"])
    low     = float(msg["k"]["l"])
    close   = float(msg["k"]["c"])
    volume  = float(msg["k"]["v"])
    complete=       msg["k"]["x"]
    
    # print out
    print("Time: {} | Price: {}".format(event_time, close))
    
    # feed df (add new bar / update latest bar)
    df.loc[start_time] = [first, high, low, close, volume, complete]

# %%
twm = ThreadedWebsocketManager()
twm.start()

# %% [markdown]
# valid intervals - 1m, 3m, 5m, 15m, 30m, 1h, 2h, 4h, 6h, 8h, 12h, 1d, 3d, 1w, 1M

# %%
twm.start_kline_socket(callback = stream_candles, symbol = "BTCUSDT", interval = "1m")

# %%
twm.stop()

# %%
df

# %%
df.info()

# %% [markdown]
# ## Creating a Test Order

# %%
from binance.client import Client

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com")

# %%
# place a test market buy order, to place an actual order use the create_order function
order = client.create_test_order(symbol = "BTCEUR", side = "BUY", type = "MARKET", quantity = 0.1)

# %%
order

# %% [markdown]
# -> Paper Trading in the __Spot Testnet__ (see next Lectures)!!!
